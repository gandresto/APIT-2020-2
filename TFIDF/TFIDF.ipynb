# %% [markdown]
# # Term Frecuency x Inverse Document Frecuency (TF IDF)

# %%
import io
import re
from functools import reduce
from collections import Counter
from numpy import log
from pandas import DataFrame

# %%
with io.open('stop-words-spanish.txt', mode='r', encoding='utf-8') as f:
    stopwords = f.read().splitlines()
stopwords
# Out:
# ['a',
#  'al',
#  'algo',
#  'algunas',
#  'algunos',
#  'ante',
#  'antes',
#  'como',
#  'con',
#  'contra',
#  'cual',
#  'cuando',
#  'de',
#  'del',
#  'desde',
#  'donde',
#  'durante',
#  'e',
#  'el',
#  'ella',
#  'ellas',
#  'ellos',
#  'en',
#  'entre',
#  'era',
#  'erais',
#  'eran',
#  'eras',
#  'eres',
#  'es',
#  'esa',
#  'esas',
#  'ese',
#  'eso',
#  'esos',
#  'esta',
#  'estaba',
#  'estabais',
#  'estaban',
#  'estabas',
#  'estad',
#  'estada',
#  'estadas',
#  'estado',
#  'estados',
#  'estamos',
#  'estando',
#  'estar',
#  'estaremos',
#  'estará',
#  'estarán',
#  'estarás',
#  'estaré',
#  'estaréis',
#  'estaría',
#  'estaríais',
#  'estaríamos',
#  'estarían',
#  'estarías',
#  'estas',
#  'este',
#  'estemos',
#  'esto',
#  'estos',
#  'estoy',
#  'estuve',
#  'estuviera',
#  'estuvierais',
#  'estuvieran',
#  'estuvieras',
#  'estuvieron',
#  'estuviese',
#  'estuvieseis',
#  'estuviesen',
#  'estuvieses',
#  'estuvimos',
#  'estuviste',
#  'estuvisteis',
#  'estuviéramos',
#  'estuviésemos',
#  'estuvo',
#  'está',
#  'estábamos',
#  'estáis',
#  'están',
#  'estás',
#  'esté',
#  'estéis',
#  'estén',
#  'estés',
#  'fue',
#  'fuera',
#  'fuerais',
#  'fueran',
#  'fueras',
#  'fueron',
#  'fuese',
#  'fueseis',
#  'fuesen',
#  'fueses',
#  'fui',
#  'fuimos',
#  'fuiste',
#  'fuisteis',
#  'fuéramos',
#  'fuésemos',
#  'ha',
#  'habida',
#  'habidas',
#  'habido',
#  'habidos',
#  'habiendo',
#  'habremos',
#  'habrá',
#  'habrán',
#  'habrás',
#  'habré',
#  'habréis',
#  'habría',
#  'habríais',
#  'habríamos',
#  'habrían',
#  'habrías',
#  'habéis',
#  'había',
#  'habíais',
#  'habíamos',
#  'habían',
#  'habías',
#  'han',
#  'has',
#  'hasta',
#  'hay',
#  'haya',
#  'hayamos',
#  'hayan',
#  'hayas',
#  'hayáis',
#  'he',
#  'hemos',
#  'hube',
#  'hubiera',
#  'hubierais',
#  'hubieran',
#  'hubieras',
#  'hubieron',
#  'hubiese',
#  'hubieseis',
#  'hubiesen',
#  'hubieses',
#  'hubimos',
#  'hubiste',
#  'hubisteis',
#  'hubiéramos',
#  'hubiésemos',
#  'hubo',
#  'la',
#  'las',
#  'le',
#  'les',
#  'lo',
#  'los',
#  'me',
#  'mi',
#  'mis',
#  'mucho',
#  'muchos',
#  'muy',
#  'más',
#  'mí',
#  'mía',
#  'mías',
#  'mío',
#  'míos',
#  'nada',
#  'ni',
#  'no',
#  'nos',
#  'nosotras',
#  'nosotros',
#  'nuestra',
#  'nuestras',
#  'nuestro',
#  'nuestros',
#  'o',
#  'os',
#  'otra',
#  'otras',
#  'otro',
#  'otros',
#  'para',
#  'pero',
#  'poco',
#  'por',
#  'porque',
#  'que',
#  'quien',
#  'quienes',
#  'qué',
#  'se',
#  'sea',
#  'seamos',
#  'sean',
#  'seas',
#  'seremos',
#  'será',
#  'serán',
#  'serás',
#  'seré',
#  'seréis',
#  'sería',
#  'seríais',
#  'seríamos',
#  'serían',
#  'serías',
#  'seáis',
#  'sido',
#  'siendo',
#  'sin',
#  'sobre',
#  'sois',
#  'somos',
#  'son',
#  'soy',
#  'su',
#  'sus',
#  'suya',
#  'suyas',
#  'suyo',
#  'suyos',
#  'sí',
#  'también',
#  'tanto',
#  'te',
#  'tendremos',
#  'tendrá',
#  'tendrán',
#  'tendrás',
#  'tendré',
#  'tendréis',
#  'tendría',
#  'tendríais',
#  'tendríamos',
#  'tendrían',
#  'tendrías',
#  'tened',
#  'tenemos',
#  'tenga',
#  'tengamos',
#  'tengan',
#  'tengas',
#  'tengo',
#  'tengáis',
#  'tenida',
#  'tenidas',
#  'tenido',
#  'tenidos',
#  'teniendo',
#  'tenéis',
#  'tenía',
#  'teníais',
#  'teníamos',
#  'tenían',
#  'tenías',
#  'ti',
#  'tiene',
#  'tienen',
#  'tienes',
#  'todo',
#  'todos',
#  'tu',
#  'tus',
#  'tuve',
#  'tuviera',
#  'tuvierais',
#  'tuvieran',
#  'tuvieras',
#  'tuvieron',
#  'tuviese',
#  'tuvieseis',
#  'tuviesen',
#  'tuvieses',
#  'tuvimos',
#  'tuviste',
#  'tuvisteis',
#  'tuviéramos',
#  'tuviésemos',
#  'tuvo',
#  'tuya',
#  'tuyas',
#  'tuyo',
#  'tuyos',
#  'tú',
#  'un',
#  'una',
#  'uno',
#  'unos',
#  'vosotras',
#  'vosotros',
#  'vuestra',
#  'vuestras',
#  'vuestro',
#  'vuestros',
#  'y',
#  'ya',
#  'yo',
#  'él',
#  'éramos']

# %%
with io.open('Data/AMLO_28042013.txt', mode='r', encoding='utf-8') as f:
    boletin = f.read().splitlines()
boletin
# Out:
# ['Andrés Manuel López Obrador denunció que ex gobernadores del estado de México –desde Carlos Hank hasta Enrique Peña— acumularon, en los últimos 30 años, alrededor de 2 mil millones de dólares en bienes y riquezas y son quienes asaltaron la Presidencia de la República como Enrique Peña, Emilio Chuayffet, Arturo Montiel y César Camacho.',
#  'Durante la asamblea de toma de protesta del comité municipal de MORENA, en Metepec y al conceder una entrevista, López Obrador manifestó su indignación, porque la entidad mexiquense es el estado con más corrupción en todo el país, pero al mismo tiempo es el primero lugar de pobreza, porque hay 7 millones de pobres y 2.5 millones de extrema pobreza.',
#  'Informó que en la administración de Enrique Peña se endeudó al estado de México y a sus 125 municipios, y ahora las alcaldías están sin dinero, se les autorizó la adquisición de más deuda, todo esto porque se comprometieron las participaciones federales.',
#  'Informó que en 2013 la economía mexicana solo crecerá 2.5 por ciento, eso significa que solo se generarán 300 mil trabajos para los jóvenes que van ingresando al mercado laboral, sin embargo quedarán en el desempleo 700 mil personas, porque se necesita impulsar, anualmente, un millón de trabajos.',
#  'Manifestó que para cubrir toda la demanda laboral, la economía necesitaría crecer, a una tasa promedio anual, de cuando menos 6 por ciento, porque de lo contrario 700 mil jóvenes se quedarán sin posibilidad de trabajo y tendrán que refugiarse en la economía informal.',
#  'López Obrador dio un dato sobre que actualmente la mitad de la población económicamente activa, en edad de trabajar, se encuentra en la economía informal y si sigue esta tendencia, para el 2018, el 65 por ciento de los mexicanos van a estar sobreviviendo en la economía informal.',
#  'Propuso que el gobierno peñista debe atender la problemática del desempleo, en vez de auspiciar la carestía, aumentar los precios de los energéticos como lo hizo el panista Felipe Calderón y ahora lo hace el priista Enrique Peña o aplicar el IVA en alimentos, medicamentos.',
#  'Al explicar que MORENA lucha para lograr la transformación del país, de manera pacífica y sin violencia, López Obrador retomó el pensamiento de un joven de Tejupilco: “a los potentados les preocupa, le temen más a un pueblo consciente y organizado, que a un pueblo enojado y violento”.',
#  'Indicó que el muchacho tiene razón, porque caer en la violencia es una trampa, los que mal gobiernan el país quisieran que se perdieran los estribos y cayéramos en la provocación. “La violencia no es el camino, la violencia en vez de destruir el autoritarismo, lo perpetua. Por eso, MORENA es un movimiento es pacífico y requiere de mucha organización y de mucha paciencia”, mencionó.',
#  'López Obrador invitó los ciudadanos de Metepec a participar el próximo 3 de noviembre a la asamblea estatal del Movimiento Regeneración Nacional que se llevará a cabo en la Plaza de los Mártires, en la capital del estado.',
#  'Y más tarde asistió a la ceremonia de toma de protesta de los integrantes del comité municipal de MORENA en Huixquilucan, estado de México.',
#  'Del jueves al domingo, Andrés Manuel López Obrador recorrió los municipios de Zitácuaro, Michoacán; Valle de Bravo, Tejupilco, San Miguel Zinacantepec, Atlacomulco, Ixtlahuaca, Toluca, Tenancingo de Degollado, Metepec y Huixquilucan, estado de México.']

# %% [markdown]
# ### Obtener palabras
#
# Obtenemos las palabras en minúsculas

# %%
documentos = [re.findall('[a-zA-zñáéíóúüÁÉÍÓÚÜÑ]+', parrafo.lower()) for (index, parrafo) in enumerate(boletin)]
documentos
# Out:
# [['andrés',
#   'manuel',
#   'lópez',
#   'obrador',
#   'denunció',
#   'que',
#   'ex',
#   'gobernadores',
#   'del',
#   'estado',
#   'de',
#   'méxico',
#   'desde',
#   'carlos',
#   'hank',
#   'hasta',
#   'enrique',
#   'peña',
#   'acumularon',
#   'en',
#   'los',
#   'últimos',
#   'años',
#   'alrededor',
#   'de',
#   'mil',
#   'millones',
#   'de',
#   'dólares',
#   'en',
#   'bienes',
#   'y',
#   'riquezas',
#   'y',
#   'son',
#   'quienes',
#   'asaltaron',
#   'la',
#   'presidencia',
#   'de',
#   'la',
#   'república',
#   'como',
#   'enrique',
#   'peña',
#   'emilio',
#   'chuayffet',
#   'arturo',
#   'montiel',
#   'y',
#   'césar',
#   'camacho'],
#  ['durante',
#   'la',
#   'asamblea',
#   'de',
#   'toma',
#   'de',
#   'protesta',
#   'del',
#   'comité',
#   'municipal',
#   'de',
#   'morena',
#   'en',
#   'metepec',
#   'y',
#   'al',
#   'conceder',
#   'una',
#   'entrevista',
#   'lópez',
#   'obrador',
#   'manifestó',
#   'su',
#   'indignación',
#   'porque',
#   'la',
#   'entidad',
#   'mexiquense',
#   'es',
#   'el',
#   'estado',
#   'con',
#   'más',
#   'corrupción',
#   'en',
#   'todo',
#   'el',
#   'país',
#   'pero',
#   'al',
#   'mismo',
#   'tiempo',
#   'es',
#   'el',
#   'primero',
#   'lugar',
#   'de',
#   'pobreza',
#   'porque',
#   'hay',
#   'millones',
#   'de',
#   'pobres',
#   'y',
#   'millones',
#   'de',
#   'extrema',
#   'pobreza'],
#  ['informó',
#   'que',
#   'en',
#   'la',
#   'administración',
#   'de',
#   'enrique',
#   'peña',
#   'se',
#   'endeudó',
#   'al',
#   'estado',
#   'de',
#   'méxico',
#   'y',
#   'a',
#   'sus',
#   'municipios',
#   'y',
#   'ahora',
#   'las',
#   'alcaldías',
#   'están',
#   'sin',
#   'dinero',
#   'se',
#   'les',
#   'autorizó',
#   'la',
#   'adquisición',
#   'de',
#   'más',
#   'deuda',
#   'todo',
#   'esto',
#   'porque',
#   'se',
#   'comprometieron',
#   'las',
#   'participaciones',
#   'federales'],
#  ['es',
#   'un',
#   'estado',
#   'de',
#   'contrastes',
#   'de',
#   'mucha',
#   'corrupción',
#   'mucha',
#   'pobreza',
#   'y',
#   'mucho',
#   'abandono',
#   'pero',
#   'como',
#   'si',
#   'fuese',
#   'el',
#   'modelo',
#   'a',
#   'seguir',
#   'se',
#   'les',
#   'premia',
#   'y',
#   'ahora',
#   'están',
#   'ya',
#   'a',
#   'cargo',
#   'de',
#   'lo',
#   'nacional',
#   'contrastó',
#   'lópez',
#   'obrador'],
#  ['qué',
#   'esperanza',
#   'se',
#   'puede',
#   'tener',
#   'igual',
#   'en',
#   'nayarit',
#   'en',
#   'yucatán',
#   'y',
#   'en',
#   'tabasco',
#   'que',
#   'no',
#   'les',
#   'conocen',
#   'los',
#   'ciudadanos',
#   'esperan',
#   'que',
#   'las',
#   'cosas',
#   'mejoren',
#   'con',
#   'los',
#   'priistas',
#   'peña',
#   'chuayffet',
#   'camacho',
#   'con',
#   'del',
#   'mazo',
#   'junior',
#   'o',
#   'la',
#   'asesoría',
#   'de',
#   'montiel',
#   'mencionó'],
#  ['al',
#   'exhibir',
#   'que',
#   'en',
#   'metepec',
#   'se',
#   'observan',
#   'colonias',
#   'de',
#   'opulencia',
#   'y',
#   'colonias',
#   'con',
#   'gente',
#   'muy',
#   'pobre',
#   'andrés',
#   'manuel',
#   'lópez',
#   'obrador',
#   'llamó',
#   'a',
#   'los',
#   'ciudadanos',
#   'a',
#   'no',
#   'ver',
#   'con',
#   'malos',
#   'ojos',
#   'a',
#   'los',
#   'que',
#   'viven',
#   'en',
#   'las',
#   'colonias',
#   'con',
#   'residencias',
#   'de',
#   'lujo',
#   'porque',
#   'hay',
#   'muchas',
#   'personas',
#   'que',
#   'lo',
#   'que',
#   'tienen',
#   'lo',
#   'han',
#   'hecho',
#   'contra',
#   'bajo',
#   'y',
#   'de',
#   'conformidad',
#   'con',
#   'la',
#   'ley'],
#  ['nosotros',
#   'estamos',
#   'en',
#   'contra',
#   'de',
#   'la',
#   'riqueza',
#   'mala',
#   'habida',
#   'de',
#   'quienes',
#   'de',
#   'la',
#   'noche',
#   'a',
#   'la',
#   'mañana',
#   'acumulan',
#   'grandes',
#   'fortunas',
#   'y',
#   'no',
#   'todos',
#   'los',
#   'ricos',
#   'de',
#   'metepec',
#   'son',
#   'como',
#   'peña',
#   'nieto',
#   'o',
#   'como',
#   'montiel',
#   'hay',
#   'que',
#   'hablar',
#   'con',
#   'quienes',
#   'le',
#   'han',
#   'ido',
#   'bien',
#   'en',
#   'la',
#   'vida',
#   'y',
#   'convencerlos',
#   'de',
#   'que',
#   'es',
#   'necesario',
#   'el',
#   'cambio',
#   'subrayó'],
#  ['recordó',
#   'que',
#   'hace',
#   'años',
#   'habló',
#   'de',
#   'que',
#   'por',
#   'el',
#   'bien',
#   'de',
#   'todos',
#   'primero',
#   'los',
#   'pobres',
#   'pero',
#   'se',
#   'mal',
#   'interpretó',
#   'pero',
#   'cómo',
#   'vamos',
#   'a',
#   'tener',
#   'tranquilidad',
#   'y',
#   'paz',
#   'social',
#   'si',
#   'sigue',
#   'habiendo',
#   'pobreza',
#   'nos',
#   'conviene',
#   'a',
#   'todos',
#   'que',
#   'haya',
#   'justicia',
#   'si',
#   'queremos',
#   'todos',
#   'vivir',
#   'en',
#   'paz',
#   'que',
#   'haya',
#   'seguridad',
#   'necesitamos',
#   'entre',
#   'todos',
#   'garantizar',
#   'que',
#   'haya',
#   'justicia',
#   'en',
#   'nuestro',
#   'país',
#   'no',
#   'está',
#   'monstruosa',
#   'desigualdad',
#   'social',
#   'que',
#   'se',
#   'padece'],
#  ['durante',
#   'una',
#   'entrevista',
#   'lópez',
#   'obrador',
#   'exhorta',
#   'a',
#   'los',
#   'estudiantes',
#   'a',
#   'que',
#   'planteen',
#   'una',
#   'propuesta',
#   'a',
#   'las',
#   'autoridades',
#   'de',
#   'la',
#   'universidad',
#   'nacional',
#   'autónomo',
#   'de',
#   'méxico',
#   'unam',
#   'de',
#   'que',
#   'liberarán',
#   'las',
#   'instalaciones',
#   'de',
#   'la',
#   'rectoría',
#   'si',
#   'obtienen',
#   'el',
#   'compromiso',
#   'de',
#   'que',
#   'van',
#   'a',
#   'ser',
#   'recibimos',
#   'posteriormente',
#   'por',
#   'el',
#   'rector',
#   'josé',
#   'narro',
#   'para',
#   'que',
#   'den',
#   'a',
#   'conocer',
#   'sus',
#   'legítimas',
#   'demandas'],
#  ['mencionó',
#   'que',
#   'esa',
#   'acción',
#   'es',
#   'para',
#   'que',
#   'las',
#   'autoridades',
#   'de',
#   'la',
#   'unam',
#   'observen',
#   'que',
#   'los',
#   'alumnos',
#   'quieren',
#   'dialogar',
#   'y',
#   'no',
#   'caer',
#   'en',
#   'la',
#   'confrontación',
#   'y',
#   'además',
#   'en',
#   'el',
#   'podrían',
#   'estar',
#   'los',
#   'medios',
#   'de',
#   'comunicación'],
#  ['es',
#   'sencillo',
#   'si',
#   'se',
#   'empecinan',
#   'las',
#   'partes',
#   'y',
#   'solo',
#   'apuestan',
#   'a',
#   'la',
#   'confrontación',
#   'y',
#   'a',
#   'la',
#   'violencia',
#   'no',
#   'se',
#   'va',
#   'a',
#   'llegar',
#   'a',
#   'ningún',
#   'lado',
#   'se',
#   'debe',
#   'garantizar',
#   'la',
#   'autonomía',
#   'y',
#   'que',
#   'no',
#   'entre',
#   'la',
#   'policía',
#   'a',
#   'la',
#   'universidad',
#   'pero',
#   'que',
#   'al',
#   'mismo',
#   'tiempo',
#   'quienes',
#   'están',
#   'en',
#   'la',
#   'rectoría',
#   'actúen',
#   'responsablemente',
#   'opinó'],
#  ['sobre',
#   'el',
#   'movimiento',
#   'magisterial',
#   'mencionó',
#   'que',
#   'se',
#   'debe',
#   'de',
#   'revisar',
#   'la',
#   'llamada',
#   'reforma',
#   'educativa',
#   'que',
#   'no',
#   'es',
#   'para',
#   'mejorar',
#   'la',
#   'calidad',
#   'de',
#   'enseñanza',
#   'o',
#   'para',
#   'dar',
#   'más',
#   'oportunidades',
#   'de',
#   'estudiar',
#   'sino',
#   'es',
#   'un',
#   'asunto',
#   'laboral',
#   'y',
#   'político',
#   'es',
#   'necesario',
#   'que',
#   'se',
#   'escuchen',
#   'a',
#   'los',
#   'maestros',
#   'que',
#   'haya',
#   'diálogo',
#   'por',
#   'parte',
#   'de',
#   'las',
#   'autoridades',
#   'federales',
#   'y',
#   'estatales'],
#  ['al',
#   'asegurar',
#   'que',
#   'movimiento',
#   'regeneración',
#   'nacional',
#   'lucha',
#   'por',
#   'los',
#   'que',
#   'menos',
#   'tienen',
#   'pero',
#   'también',
#   'por',
#   'quienes',
#   'nos',
#   'ven',
#   'con',
#   'malos',
#   'ojos',
#   'lópez',
#   'obrador',
#   'expresó',
#   'no',
#   'importa',
#   'quién',
#   'esté',
#   'en',
#   'la',
#   'presidencia',
#   'de',
#   'la',
#   'república',
#   'antes',
#   'estaba',
#   'el',
#   'pan',
#   'y',
#   'ahora',
#   'está',
#   'el',
#   'pri',
#   'sin',
#   'embargo',
#   'está',
#   'empeorando',
#   'la',
#   'situación',
#   'económica',
#   'política',
#   'y',
#   'social',
#   'del',
#   'país',
#   'porque',
#   'todo',
#   'es',
#   'pura',
#   'publicidad',
#   'es',
#   'puro',
#   'circo'],
#  ['durante',
#   'la',
#   'asamblea',
#   'subrayó',
#   'que',
#   'mientras',
#   'siga',
#   'inalterable',
#   'la',
#   'política',
#   'económica',
#   'antipopular',
#   'y',
#   'entreguista',
#   'que',
#   'sólo',
#   'beneficia',
#   'una',
#   'pequeña',
#   'minoría',
#   'a',
#   'costa',
#   'del',
#   'sufrimiento',
#   'del',
#   'pueblo',
#   'de',
#   'méxico',
#   'continuará',
#   'la',
#   'crisis',
#   'económica',
#   'de',
#   'bienestar',
#   'social',
#   'de',
#   'inseguridad',
#   'y',
#   'de',
#   'violencia',
#   'que',
#   'se',
#   'padece',
#   'el',
#   'país'],
#  ['expuso',
#   'que',
#   'ni',
#   'por',
#   'equivocación',
#   'enrique',
#   'peña',
#   'habla',
#   'de',
#   'que',
#   'va',
#   'a',
#   'impulsar',
#   'las',
#   'actividades',
#   'productivas',
#   'o',
#   'generar',
#   'empleos',
#   'que',
#   'es',
#   'el',
#   'principal',
#   'problema',
#   'de',
#   'la',
#   'nación',
#   'porque',
#   'no',
#   'hay',
#   'desde',
#   'hace',
#   'años',
#   'crecimiento',
#   'económico',
#   'si',
#   'no',
#   'hay',
#   'crecimiento',
#   'económico',
#   'no',
#   'hay',
#   'empleos',
#   'si',
#   'no',
#   'hay',
#   'empleos',
#   'no',
#   'hay',
#   'bienestar',
#   'si',
#   'no',
#   'hay',
#   'bienestar',
#   'no',
#   'puede',
#   'haber',
#   'tranquilidad',
#   'y',
#   'paz',
#   'social'],
#  ['informó',
#   'que',
#   'en',
#   'la',
#   'economía',
#   'mexicana',
#   'solo',
#   'crecerá',
#   'por',
#   'ciento',
#   'eso',
#   'significa',
#   'que',
#   'solo',
#   'se',
#   'generarán',
#   'mil',
#   'trabajos',
#   'para',
#   'los',
#   'jóvenes',
#   'que',
#   'van',
#   'ingresando',
#   'al',
#   'mercado',
#   'laboral',
#   'sin',
#   'embargo',
#   'quedarán',
#   'en',
#   'el',
#   'desempleo',
#   'mil',
#   'personas',
#   'porque',
#   'se',
#   'necesita',
#   'impulsar',
#   'anualmente',
#   'un',
#   'millón',
#   'de',
#   'trabajos'],
#  ['manifestó',
#   'que',
#   'para',
#   'cubrir',
#   'toda',
#   'la',
#   'demanda',
#   'laboral',
#   'la',
#   'economía',
#   'necesitaría',
#   'crecer',
#   'a',
#   'una',
#   'tasa',
#   'promedio',
#   'anual',
#   'de',
#   'cuando',
#   'menos',
#   'por',
#   'ciento',
#   'porque',
#   'de',
#   'lo',
#   'contrario',
#   'mil',
#   'jóvenes',
#   'se',
#   'quedarán',
#   'sin',
#   'posibilidad',
#   'de',
#   'trabajo',
#   'y',
#   'tendrán',
#   'que',
#   'refugiarse',
#   'en',
#   'la',
#   'economía',
#   'informal'],
#  ['lópez',
#   'obrador',
#   'dio',
#   'un',
#   'dato',
#   'sobre',
#   'que',
#   'actualmente',
#   'la',
#   'mitad',
#   'de',
#   'la',
#   'población',
#   'económicamente',
#   'activa',
#   'en',
#   'edad',
#   'de',
#   'trabajar',
#   'se',
#   'encuentra',
#   'en',
#   'la',
#   'economía',
#   'informal',
#   'y',
#   'si',
#   'sigue',
#   'esta',
#   'tendencia',
#   'para',
#   'el',
#   'el',
#   'por',
#   'ciento',
#   'de',
#   'los',
#   'mexicanos',
#   'van',
#   'a',
#   'estar',
#   'sobreviviendo',
#   'en',
#   'la',
#   'economía',
#   'informal'],
#  ['propuso',
#   'que',
#   'el',
#   'gobierno',
#   'peñista',
#   'debe',
#   'atender',
#   'la',
#   'problemática',
#   'del',
#   'desempleo',
#   'en',
#   'vez',
#   'de',
#   'auspiciar',
#   'la',
#   'carestía',
#   'aumentar',
#   'los',
#   'precios',
#   'de',
#   'los',
#   'energéticos',
#   'como',
#   'lo',
#   'hizo',
#   'el',
#   'panista',
#   'felipe',
#   'calderón',
#   'y',
#   'ahora',
#   'lo',
#   'hace',
#   'el',
#   'priista',
#   'enrique',
#   'peña',
#   'o',
#   'aplicar',
#   'el',
#   'iva',
#   'en',
#   'alimentos',
#   'medicamentos'],
#  ['al',
#   'explicar',
#   'que',
#   'morena',
#   'lucha',
#   'para',
#   'lograr',
#   'la',
#   'transformación',
#   'del',
#   'país',
#   'de',
#   'manera',
#   'pacífica',
#   'y',
#   'sin',
#   'violencia',
#   'lópez',
#   'obrador',
#   'retomó',
#   'el',
#   'pensamiento',
#   'de',
#   'un',
#   'joven',
#   'de',
#   'tejupilco',
#   'a',
#   'los',
#   'potentados',
#   'les',
#   'preocupa',
#   'le',
#   'temen',
#   'más',
#   'a',
#   'un',
#   'pueblo',
#   'consciente',
#   'y',
#   'organizado',
#   'que',
#   'a',
#   'un',
#   'pueblo',
#   'enojado',
#   'y',
#   'violento'],
#  ['indicó',
#   'que',
#   'el',
#   'muchacho',
#   'tiene',
#   'razón',
#   'porque',
#   'caer',
#   'en',
#   'la',
#   'violencia',
#   'es',
#   'una',
#   'trampa',
#   'los',
#   'que',
#   'mal',
#   'gobiernan',
#   'el',
#   'país',
#   'quisieran',
#   'que',
#   'se',
#   'perdieran',
#   'los',
#   'estribos',
#   'y',
#   'cayéramos',
#   'en',
#   'la',
#   'provocación',
#   'la',
#   'violencia',
#   'no',
#   'es',
#   'el',
#   'camino',
#   'la',
#   'violencia',
#   'en',
#   'vez',
#   'de',
#   'destruir',
#   'el',
#   'autoritarismo',
#   'lo',
#   'perpetua',
#   'por',
#   'eso',
#   'morena',
#   'es',
#   'un',
#   'movimiento',
#   'es',
#   'pacífico',
#   'y',
#   'requiere',
#   'de',
#   'mucha',
#   'organización',
#   'y',
#   'de',
#   'mucha',
#   'paciencia',
#   'mencionó'],
#  ['lópez',
#   'obrador',
#   'invitó',
#   'los',
#   'ciudadanos',
#   'de',
#   'metepec',
#   'a',
#   'participar',
#   'el',
#   'próximo',
#   'de',
#   'noviembre',
#   'a',
#   'la',
#   'asamblea',
#   'estatal',
#   'del',
#   'movimiento',
#   'regeneración',
#   'nacional',
#   'que',
#   'se',
#   'llevará',
#   'a',
#   'cabo',
#   'en',
#   'la',
#   'plaza',
#   'de',
#   'los',
#   'mártires',
#   'en',
#   'la',
#   'capital',
#   'del',
#   'estado'],
#  ['y',
#   'más',
#   'tarde',
#   'asistió',
#   'a',
#   'la',
#   'ceremonia',
#   'de',
#   'toma',
#   'de',
#   'protesta',
#   'de',
#   'los',
#   'integrantes',
#   'del',
#   'comité',
#   'municipal',
#   'de',
#   'morena',
#   'en',
#   'huixquilucan',
#   'estado',
#   'de',
#   'méxico'],
#  ['del',
#   'jueves',
#   'al',
#   'domingo',
#   'andrés',
#   'manuel',
#   'lópez',
#   'obrador',
#   'recorrió',
#   'los',
#   'municipios',
#   'de',
#   'zitácuaro',
#   'michoacán',
#   'valle',
#   'de',
#   'bravo',
#   'tejupilco',
#   'san',
#   'miguel',
#   'zinacantepec',
#   'atlacomulco',
#   'ixtlahuaca',
#   'toluca',
#   'tenancingo',
#   'de',
#   'degollado',
#   'metepec',
#   'y',
#   'huixquilucan',
#   'estado',
#   'de',
#   'méxico']]

# %%
documentos = [[palabra for palabra in documento if not (palabra in stopwords)] for documento in documentos]
total_palabras = len(documentos)
documentos
# Out:
# [['andrés',
#   'manuel',
#   'lópez',
#   'obrador',
#   'denunció',
#   'ex',
#   'gobernadores',
#   'méxico',
#   'carlos',
#   'hank',
#   'enrique',
#   'peña',
#   'acumularon',
#   'últimos',
#   'años',
#   'alrededor',
#   'mil',
#   'millones',
#   'dólares',
#   'bienes',
#   'riquezas',
#   'asaltaron',
#   'presidencia',
#   'república',
#   'enrique',
#   'peña',
#   'emilio',
#   'chuayffet',
#   'arturo',
#   'montiel',
#   'césar',
#   'camacho'],
#  ['asamblea',
#   'toma',
#   'protesta',
#   'comité',
#   'municipal',
#   'morena',
#   'metepec',
#   'conceder',
#   'entrevista',
#   'lópez',
#   'obrador',
#   'manifestó',
#   'indignación',
#   'entidad',
#   'mexiquense',
#   'corrupción',
#   'país',
#   'mismo',
#   'tiempo',
#   'primero',
#   'lugar',
#   'pobreza',
#   'millones',
#   'pobres',
#   'millones',
#   'extrema',
#   'pobreza'],
#  ['informó',
#   'administración',
#   'enrique',
#   'peña',
#   'endeudó',
#   'méxico',
#   'municipios',
#   'ahora',
#   'alcaldías',
#   'dinero',
#   'autorizó',
#   'adquisición',
#   'deuda',
#   'comprometieron',
#   'participaciones',
#   'federales'],
#  ['contrastes',
#   'mucha',
#   'corrupción',
#   'mucha',
#   'pobreza',
#   'abandono',
#   'si',
#   'modelo',
#   'seguir',
#   'premia',
#   'ahora',
#   'cargo',
#   'nacional',
#   'contrastó',
#   'lópez',
#   'obrador'],
#  ['esperanza',
#   'puede',
#   'tener',
#   'igual',
#   'nayarit',
#   'yucatán',
#   'tabasco',
#   'conocen',
#   'ciudadanos',
#   'esperan',
#   'cosas',
#   'mejoren',
#   'priistas',
#   'peña',
#   'chuayffet',
#   'camacho',
#   'mazo',
#   'junior',
#   'asesoría',
#   'montiel',
#   'mencionó'],
#  ['exhibir',
#   'metepec',
#   'observan',
#   'colonias',
#   'opulencia',
#   'colonias',
#   'gente',
#   'pobre',
#   'andrés',
#   'manuel',
#   'lópez',
#   'obrador',
#   'llamó',
#   'ciudadanos',
#   'ver',
#   'malos',
#   'ojos',
#   'viven',
#   'colonias',
#   'residencias',
#   'lujo',
#   'muchas',
#   'personas',
#   'hecho',
#   'bajo',
#   'conformidad',
#   'ley'],
#  ['riqueza',
#   'mala',
#   'noche',
#   'mañana',
#   'acumulan',
#   'grandes',
#   'fortunas',
#   'ricos',
#   'metepec',
#   'peña',
#   'nieto',
#   'montiel',
#   'hablar',
#   'ido',
#   'bien',
#   'vida',
#   'convencerlos',
#   'necesario',
#   'cambio',
#   'subrayó'],
#  ['recordó',
#   'hace',
#   'años',
#   'habló',
#   'bien',
#   'primero',
#   'pobres',
#   'mal',
#   'interpretó',
#   'cómo',
#   'vamos',
#   'tener',
#   'tranquilidad',
#   'paz',
#   'social',
#   'si',
#   'sigue',
#   'pobreza',
#   'conviene',
#   'justicia',
#   'si',
#   'queremos',
#   'vivir',
#   'paz',
#   'seguridad',
#   'necesitamos',
#   'garantizar',
#   'justicia',
#   'país',
#   'monstruosa',
#   'desigualdad',
#   'social',
#   'padece'],
#  ['entrevista',
#   'lópez',
#   'obrador',
#   'exhorta',
#   'estudiantes',
#   'planteen',
#   'propuesta',
#   'autoridades',
#   'universidad',
#   'nacional',
#   'autónomo',
#   'méxico',
#   'unam',
#   'liberarán',
#   'instalaciones',
#   'rectoría',
#   'si',
#   'obtienen',
#   'compromiso',
#   'van',
#   'ser',
#   'recibimos',
#   'posteriormente',
#   'rector',
#   'josé',
#   'narro',
#   'den',
#   'conocer',
#   'legítimas',
#   'demandas'],
#  ['mencionó',
#   'acción',
#   'autoridades',
#   'unam',
#   'observen',
#   'alumnos',
#   'quieren',
#   'dialogar',
#   'caer',
#   'confrontación',
#   'además',
#   'podrían',
#   'medios',
#   'comunicación'],
#  ['sencillo',
#   'si',
#   'empecinan',
#   'partes',
#   'solo',
#   'apuestan',
#   'confrontación',
#   'violencia',
#   'va',
#   'llegar',
#   'ningún',
#   'lado',
#   'debe',
#   'garantizar',
#   'autonomía',
#   'policía',
#   'universidad',
#   'mismo',
#   'tiempo',
#   'rectoría',
#   'actúen',
#   'responsablemente',
#   'opinó'],
#  ['movimiento',
#   'magisterial',
#   'mencionó',
#   'debe',
#   'revisar',
#   'llamada',
#   'reforma',
#   'educativa',
#   'mejorar',
#   'calidad',
#   'enseñanza',
#   'dar',
#   'oportunidades',
#   'estudiar',
#   'sino',
#   'asunto',
#   'laboral',
#   'político',
#   'necesario',
#   'escuchen',
#   'maestros',
#   'diálogo',
#   'parte',
#   'autoridades',
#   'federales',
#   'estatales'],
#  ['asegurar',
#   'movimiento',
#   'regeneración',
#   'nacional',
#   'lucha',
#   'menos',
#   'ven',
#   'malos',
#   'ojos',
#   'lópez',
#   'obrador',
#   'expresó',
#   'importa',
#   'quién',
#   'presidencia',
#   'república',
#   'pan',
#   'ahora',
#   'pri',
#   'embargo',
#   'empeorando',
#   'situación',
#   'económica',
#   'política',
#   'social',
#   'país',
#   'pura',
#   'publicidad',
#   'puro',
#   'circo'],
#  ['asamblea',
#   'subrayó',
#   'mientras',
#   'siga',
#   'inalterable',
#   'política',
#   'económica',
#   'antipopular',
#   'entreguista',
#   'sólo',
#   'beneficia',
#   'pequeña',
#   'minoría',
#   'costa',
#   'sufrimiento',
#   'pueblo',
#   'méxico',
#   'continuará',
#   'crisis',
#   'económica',
#   'bienestar',
#   'social',
#   'inseguridad',
#   'violencia',
#   'padece',
#   'país'],
#  ['expuso',
#   'equivocación',
#   'enrique',
#   'peña',
#   'habla',
#   'va',
#   'impulsar',
#   'actividades',
#   'productivas',
#   'generar',
#   'empleos',
#   'principal',
#   'problema',
#   'nación',
#   'hace',
#   'años',
#   'crecimiento',
#   'económico',
#   'si',
#   'crecimiento',
#   'económico',
#   'empleos',
#   'si',
#   'empleos',
#   'bienestar',
#   'si',
#   'bienestar',
#   'puede',
#   'haber',
#   'tranquilidad',
#   'paz',
#   'social'],
#  ['informó',
#   'economía',
#   'mexicana',
#   'solo',
#   'crecerá',
#   'ciento',
#   'significa',
#   'solo',
#   'generarán',
#   'mil',
#   'trabajos',
#   'jóvenes',
#   'van',
#   'ingresando',
#   'mercado',
#   'laboral',
#   'embargo',
#   'quedarán',
#   'desempleo',
#   'mil',
#   'personas',
#   'necesita',
#   'impulsar',
#   'anualmente',
#   'millón',
#   'trabajos'],
#  ['manifestó',
#   'cubrir',
#   'toda',
#   'demanda',
#   'laboral',
#   'economía',
#   'necesitaría',
#   'crecer',
#   'tasa',
#   'promedio',
#   'anual',
#   'menos',
#   'ciento',
#   'contrario',
#   'mil',
#   'jóvenes',
#   'quedarán',
#   'posibilidad',
#   'trabajo',
#   'refugiarse',
#   'economía',
#   'informal'],
#  ['lópez',
#   'obrador',
#   'dio',
#   'dato',
#   'actualmente',
#   'mitad',
#   'población',
#   'económicamente',
#   'activa',
#   'edad',
#   'trabajar',
#   'encuentra',
#   'economía',
#   'informal',
#   'si',
#   'sigue',
#   'tendencia',
#   'ciento',
#   'mexicanos',
#   'van',
#   'sobreviviendo',
#   'economía',
#   'informal'],
#  ['propuso',
#   'gobierno',
#   'peñista',
#   'debe',
#   'atender',
#   'problemática',
#   'desempleo',
#   'vez',
#   'auspiciar',
#   'carestía',
#   'aumentar',
#   'precios',
#   'energéticos',
#   'hizo',
#   'panista',
#   'felipe',
#   'calderón',
#   'ahora',
#   'hace',
#   'priista',
#   'enrique',
#   'peña',
#   'aplicar',
#   'iva',
#   'alimentos',
#   'medicamentos'],
#  ['explicar',
#   'morena',
#   'lucha',
#   'lograr',
#   'transformación',
#   'país',
#   'manera',
#   'pacífica',
#   'violencia',
#   'lópez',
#   'obrador',
#   'retomó',
#   'pensamiento',
#   'joven',
#   'tejupilco',
#   'potentados',
#   'preocupa',
#   'temen',
#   'pueblo',
#   'consciente',
#   'organizado',
#   'pueblo',
#   'enojado',
#   'violento'],
#  ['indicó',
#   'muchacho',
#   'razón',
#   'caer',
#   'violencia',
#   'trampa',
#   'mal',
#   'gobiernan',
#   'país',
#   'quisieran',
#   'perdieran',
#   'estribos',
#   'cayéramos',
#   'provocación',
#   'violencia',
#   'camino',
#   'violencia',
#   'vez',
#   'destruir',
#   'autoritarismo',
#   'perpetua',
#   'morena',
#   'movimiento',
#   'pacífico',
#   'requiere',
#   'mucha',
#   'organización',
#   'mucha',
#   'paciencia',
#   'mencionó'],
#  ['lópez',
#   'obrador',
#   'invitó',
#   'ciudadanos',
#   'metepec',
#   'participar',
#   'próximo',
#   'noviembre',
#   'asamblea',
#   'estatal',
#   'movimiento',
#   'regeneración',
#   'nacional',
#   'llevará',
#   'cabo',
#   'plaza',
#   'mártires',
#   'capital'],
#  ['tarde',
#   'asistió',
#   'ceremonia',
#   'toma',
#   'protesta',
#   'integrantes',
#   'comité',
#   'municipal',
#   'morena',
#   'huixquilucan',
#   'méxico'],
#  ['jueves',
#   'domingo',
#   'andrés',
#   'manuel',
#   'lópez',
#   'obrador',
#   'recorrió',
#   'municipios',
#   'zitácuaro',
#   'michoacán',
#   'valle',
#   'bravo',
#   'tejupilco',
#   'san',
#   'miguel',
#   'zinacantepec',
#   'atlacomulco',
#   'ixtlahuaca',
#   'toluca',
#   'tenancingo',
#   'degollado',
#   'metepec',
#   'huixquilucan',
#   'méxico']]

# %% [markdown]
# Contar las palabras por documento y el total de palabras

# %%
cuenta_por_documento = [Counter(parrafo) for parrafo in documentos]
cuenta_total_palabras = reduce((lambda x, y: x + y), cuenta_por_documento)
palabras = [palabra for (palabra, cuenta) in cuenta_total_palabras.items()]
cuenta_por_documento
# Out:
# [Counter({'andrés': 1,
#           'manuel': 1,
#           'lópez': 1,
#           'obrador': 1,
#           'denunció': 1,
#           'ex': 1,
#           'gobernadores': 1,
#           'méxico': 1,
#           'carlos': 1,
#           'hank': 1,
#           'enrique': 2,
#           'peña': 2,
#           'acumularon': 1,
#           'últimos': 1,
#           'años': 1,
#           'alrededor': 1,
#           'mil': 1,
#           'millones': 1,
#           'dólares': 1,
#           'bienes': 1,
#           'riquezas': 1,
#           'asaltaron': 1,
#           'presidencia': 1,
#           'república': 1,
#           'emilio': 1,
#           'chuayffet': 1,
#           'arturo': 1,
#           'montiel': 1,
#           'césar': 1,
#           'camacho': 1}),
#  Counter({'asamblea': 1,
#           'toma': 1,
#           'protesta': 1,
#           'comité': 1,
#           'municipal': 1,
#           'morena': 1,
#           'metepec': 1,
#           'conceder': 1,
#           'entrevista': 1,
#           'lópez': 1,
#           'obrador': 1,
#           'manifestó': 1,
#           'indignación': 1,
#           'entidad': 1,
#           'mexiquense': 1,
#           'corrupción': 1,
#           'país': 1,
#           'mismo': 1,
#           'tiempo': 1,
#           'primero': 1,
#           'lugar': 1,
#           'pobreza': 2,
#           'millones': 2,
#           'pobres': 1,
#           'extrema': 1}),
#  Counter({'informó': 1,
#           'administración': 1,
#           'enrique': 1,
#           'peña': 1,
#           'endeudó': 1,
#           'méxico': 1,
#           'municipios': 1,
#           'ahora': 1,
#           'alcaldías': 1,
#           'dinero': 1,
#           'autorizó': 1,
#           'adquisición': 1,
#           'deuda': 1,
#           'comprometieron': 1,
#           'participaciones': 1,
#           'federales': 1}),
#  Counter({'contrastes': 1,
#           'mucha': 2,
#           'corrupción': 1,
#           'pobreza': 1,
#           'abandono': 1,
#           'si': 1,
#           'modelo': 1,
#           'seguir': 1,
#           'premia': 1,
#           'ahora': 1,
#           'cargo': 1,
#           'nacional': 1,
#           'contrastó': 1,
#           'lópez': 1,
#           'obrador': 1}),
#  Counter({'esperanza': 1,
#           'puede': 1,
#           'tener': 1,
#           'igual': 1,
#           'nayarit': 1,
#           'yucatán': 1,
#           'tabasco': 1,
#           'conocen': 1,
#           'ciudadanos': 1,
#           'esperan': 1,
#           'cosas': 1,
#           'mejoren': 1,
#           'priistas': 1,
#           'peña': 1,
#           'chuayffet': 1,
#           'camacho': 1,
#           'mazo': 1,
#           'junior': 1,
#           'asesoría': 1,
#           'montiel': 1,
#           'mencionó': 1}),
#  Counter({'exhibir': 1,
#           'metepec': 1,
#           'observan': 1,
#           'colonias': 3,
#           'opulencia': 1,
#           'gente': 1,
#           'pobre': 1,
#           'andrés': 1,
#           'manuel': 1,
#           'lópez': 1,
#           'obrador': 1,
#           'llamó': 1,
#           'ciudadanos': 1,
#           'ver': 1,
#           'malos': 1,
#           'ojos': 1,
#           'viven': 1,
#           'residencias': 1,
#           'lujo': 1,
#           'muchas': 1,
#           'personas': 1,
#           'hecho': 1,
#           'bajo': 1,
#           'conformidad': 1,
#           'ley': 1}),
#  Counter({'riqueza': 1,
#           'mala': 1,
#           'noche': 1,
#           'mañana': 1,
#           'acumulan': 1,
#           'grandes': 1,
#           'fortunas': 1,
#           'ricos': 1,
#           'metepec': 1,
#           'peña': 1,
#           'nieto': 1,
#           'montiel': 1,
#           'hablar': 1,
#           'ido': 1,
#           'bien': 1,
#           'vida': 1,
#           'convencerlos': 1,
#           'necesario': 1,
#           'cambio': 1,
#           'subrayó': 1}),
#  Counter({'recordó': 1,
#           'hace': 1,
#           'años': 1,
#           'habló': 1,
#           'bien': 1,
#           'primero': 1,
#           'pobres': 1,
#           'mal': 1,
#           'interpretó': 1,
#           'cómo': 1,
#           'vamos': 1,
#           'tener': 1,
#           'tranquilidad': 1,
#           'paz': 2,
#           'social': 2,
#           'si': 2,
#           'sigue': 1,
#           'pobreza': 1,
#           'conviene': 1,
#           'justicia': 2,
#           'queremos': 1,
#           'vivir': 1,
#           'seguridad': 1,
#           'necesitamos': 1,
#           'garantizar': 1,
#           'país': 1,
#           'monstruosa': 1,
#           'desigualdad': 1,
#           'padece': 1}),
#  Counter({'entrevista': 1,
#           'lópez': 1,
#           'obrador': 1,
#           'exhorta': 1,
#           'estudiantes': 1,
#           'planteen': 1,
#           'propuesta': 1,
#           'autoridades': 1,
#           'universidad': 1,
#           'nacional': 1,
#           'autónomo': 1,
#           'méxico': 1,
#           'unam': 1,
#           'liberarán': 1,
#           'instalaciones': 1,
#           'rectoría': 1,
#           'si': 1,
#           'obtienen': 1,
#           'compromiso': 1,
#           'van': 1,
#           'ser': 1,
#           'recibimos': 1,
#           'posteriormente': 1,
#           'rector': 1,
#           'josé': 1,
#           'narro': 1,
#           'den': 1,
#           'conocer': 1,
#           'legítimas': 1,
#           'demandas': 1}),
#  Counter({'mencionó': 1,
#           'acción': 1,
#           'autoridades': 1,
#           'unam': 1,
#           'observen': 1,
#           'alumnos': 1,
#           'quieren': 1,
#           'dialogar': 1,
#           'caer': 1,
#           'confrontación': 1,
#           'además': 1,
#           'podrían': 1,
#           'medios': 1,
#           'comunicación': 1}),
#  Counter({'sencillo': 1,
#           'si': 1,
#           'empecinan': 1,
#           'partes': 1,
#           'solo': 1,
#           'apuestan': 1,
#           'confrontación': 1,
#           'violencia': 1,
#           'va': 1,
#           'llegar': 1,
#           'ningún': 1,
#           'lado': 1,
#           'debe': 1,
#           'garantizar': 1,
#           'autonomía': 1,
#           'policía': 1,
#           'universidad': 1,
#           'mismo': 1,
#           'tiempo': 1,
#           'rectoría': 1,
#           'actúen': 1,
#           'responsablemente': 1,
#           'opinó': 1}),
#  Counter({'movimiento': 1,
#           'magisterial': 1,
#           'mencionó': 1,
#           'debe': 1,
#           'revisar': 1,
#           'llamada': 1,
#           'reforma': 1,
#           'educativa': 1,
#           'mejorar': 1,
#           'calidad': 1,
#           'enseñanza': 1,
#           'dar': 1,
#           'oportunidades': 1,
#           'estudiar': 1,
#           'sino': 1,
#           'asunto': 1,
#           'laboral': 1,
#           'político': 1,
#           'necesario': 1,
#           'escuchen': 1,
#           'maestros': 1,
#           'diálogo': 1,
#           'parte': 1,
#           'autoridades': 1,
#           'federales': 1,
#           'estatales': 1}),
#  Counter({'asegurar': 1,
#           'movimiento': 1,
#           'regeneración': 1,
#           'nacional': 1,
#           'lucha': 1,
#           'menos': 1,
#           'ven': 1,
#           'malos': 1,
#           'ojos': 1,
#           'lópez': 1,
#           'obrador': 1,
#           'expresó': 1,
#           'importa': 1,
#           'quién': 1,
#           'presidencia': 1,
#           'república': 1,
#           'pan': 1,
#           'ahora': 1,
#           'pri': 1,
#           'embargo': 1,
#           'empeorando': 1,
#           'situación': 1,
#           'económica': 1,
#           'política': 1,
#           'social': 1,
#           'país': 1,
#           'pura': 1,
#           'publicidad': 1,
#           'puro': 1,
#           'circo': 1}),
#  Counter({'asamblea': 1,
#           'subrayó': 1,
#           'mientras': 1,
#           'siga': 1,
#           'inalterable': 1,
#           'política': 1,
#           'económica': 2,
#           'antipopular': 1,
#           'entreguista': 1,
#           'sólo': 1,
#           'beneficia': 1,
#           'pequeña': 1,
#           'minoría': 1,
#           'costa': 1,
#           'sufrimiento': 1,
#           'pueblo': 1,
#           'méxico': 1,
#           'continuará': 1,
#           'crisis': 1,
#           'bienestar': 1,
#           'social': 1,
#           'inseguridad': 1,
#           'violencia': 1,
#           'padece': 1,
#           'país': 1}),
#  Counter({'expuso': 1,
#           'equivocación': 1,
#           'enrique': 1,
#           'peña': 1,
#           'habla': 1,
#           'va': 1,
#           'impulsar': 1,
#           'actividades': 1,
#           'productivas': 1,
#           'generar': 1,
#           'empleos': 3,
#           'principal': 1,
#           'problema': 1,
#           'nación': 1,
#           'hace': 1,
#           'años': 1,
#           'crecimiento': 2,
#           'económico': 2,
#           'si': 3,
#           'bienestar': 2,
#           'puede': 1,
#           'haber': 1,
#           'tranquilidad': 1,
#           'paz': 1,
#           'social': 1}),
#  Counter({'informó': 1,
#           'economía': 1,
#           'mexicana': 1,
#           'solo': 2,
#           'crecerá': 1,
#           'ciento': 1,
#           'significa': 1,
#           'generarán': 1,
#           'mil': 2,
#           'trabajos': 2,
#           'jóvenes': 1,
#           'van': 1,
#           'ingresando': 1,
#           'mercado': 1,
#           'laboral': 1,
#           'embargo': 1,
#           'quedarán': 1,
#           'desempleo': 1,
#           'personas': 1,
#           'necesita': 1,
#           'impulsar': 1,
#           'anualmente': 1,
#           'millón': 1}),
#  Counter({'manifestó': 1,
#           'cubrir': 1,
#           'toda': 1,
#           'demanda': 1,
#           'laboral': 1,
#           'economía': 2,
#           'necesitaría': 1,
#           'crecer': 1,
#           'tasa': 1,
#           'promedio': 1,
#           'anual': 1,
#           'menos': 1,
#           'ciento': 1,
#           'contrario': 1,
#           'mil': 1,
#           'jóvenes': 1,
#           'quedarán': 1,
#           'posibilidad': 1,
#           'trabajo': 1,
#           'refugiarse': 1,
#           'informal': 1}),
#  Counter({'lópez': 1,
#           'obrador': 1,
#           'dio': 1,
#           'dato': 1,
#           'actualmente': 1,
#           'mitad': 1,
#           'población': 1,
#           'económicamente': 1,
#           'activa': 1,
#           'edad': 1,
#           'trabajar': 1,
#           'encuentra': 1,
#           'economía': 2,
#           'informal': 2,
#           'si': 1,
#           'sigue': 1,
#           'tendencia': 1,
#           'ciento': 1,
#           'mexicanos': 1,
#           'van': 1,
#           'sobreviviendo': 1}),
#  Counter({'propuso': 1,
#           'gobierno': 1,
#           'peñista': 1,
#           'debe': 1,
#           'atender': 1,
#           'problemática': 1,
#           'desempleo': 1,
#           'vez': 1,
#           'auspiciar': 1,
#           'carestía': 1,
#           'aumentar': 1,
#           'precios': 1,
#           'energéticos': 1,
#           'hizo': 1,
#           'panista': 1,
#           'felipe': 1,
#           'calderón': 1,
#           'ahora': 1,
#           'hace': 1,
#           'priista': 1,
#           'enrique': 1,
#           'peña': 1,
#           'aplicar': 1,
#           'iva': 1,
#           'alimentos': 1,
#           'medicamentos': 1}),
#  Counter({'explicar': 1,
#           'morena': 1,
#           'lucha': 1,
#           'lograr': 1,
#           'transformación': 1,
#           'país': 1,
#           'manera': 1,
#           'pacífica': 1,
#           'violencia': 1,
#           'lópez': 1,
#           'obrador': 1,
#           'retomó': 1,
#           'pensamiento': 1,
#           'joven': 1,
#           'tejupilco': 1,
#           'potentados': 1,
#           'preocupa': 1,
#           'temen': 1,
#           'pueblo': 2,
#           'consciente': 1,
#           'organizado': 1,
#           'enojado': 1,
#           'violento': 1}),
#  Counter({'indicó': 1,
#           'muchacho': 1,
#           'razón': 1,
#           'caer': 1,
#           'violencia': 3,
#           'trampa': 1,
#           'mal': 1,
#           'gobiernan': 1,
#           'país': 1,
#           'quisieran': 1,
#           'perdieran': 1,
#           'estribos': 1,
#           'cayéramos': 1,
#           'provocación': 1,
#           'camino': 1,
#           'vez': 1,
#           'destruir': 1,
#           'autoritarismo': 1,
#           'perpetua': 1,
#           'morena': 1,
#           'movimiento': 1,
#           'pacífico': 1,
#           'requiere': 1,
#           'mucha': 2,
#           'organización': 1,
#           'paciencia': 1,
#           'mencionó': 1}),
#  Counter({'lópez': 1,
#           'obrador': 1,
#           'invitó': 1,
#           'ciudadanos': 1,
#           'metepec': 1,
#           'participar': 1,
#           'próximo': 1,
#           'noviembre': 1,
#           'asamblea': 1,
#           'estatal': 1,
#           'movimiento': 1,
#           'regeneración': 1,
#           'nacional': 1,
#           'llevará': 1,
#           'cabo': 1,
#           'plaza': 1,
#           'mártires': 1,
#           'capital': 1}),
#  Counter({'tarde': 1,
#           'asistió': 1,
#           'ceremonia': 1,
#           'toma': 1,
#           'protesta': 1,
#           'integrantes': 1,
#           'comité': 1,
#           'municipal': 1,
#           'morena': 1,
#           'huixquilucan': 1,
#           'méxico': 1}),
#  Counter({'jueves': 1,
#           'domingo': 1,
#           'andrés': 1,
#           'manuel': 1,
#           'lópez': 1,
#           'obrador': 1,
#           'recorrió': 1,
#           'municipios': 1,
#           'zitácuaro': 1,
#           'michoacán': 1,
#           'valle': 1,
#           'bravo': 1,
#           'tejupilco': 1,
#           'san': 1,
#           'miguel': 1,
#           'zinacantepec': 1,
#           'atlacomulco': 1,
#           'ixtlahuaca': 1,
#           'toluca': 1,
#           'tenancingo': 1,
#           'degollado': 1,
#           'metepec': 1,
#           'huixquilucan': 1,
#           'méxico': 1})]

# %% [markdown]
# Definimos función para suavizar la cuenta de palabras.

# %%
def bm25(contador, k=25):
    return {
        key: ((cuenta + 1)*k)/(cuenta+k) for (key, cuenta) in contador.items()
    }

# %% [markdown]
# Calculamos tf para cada uno de los documentos

# %%
tfs = [bm25(c_doc) for c_doc in cuenta_por_documento]
tfs
# Out:
# [{'andrés': 1.9230769230769231,
#   'manuel': 1.9230769230769231,
#   'lópez': 1.9230769230769231,
#   'obrador': 1.9230769230769231,
#   'denunció': 1.9230769230769231,
#   'ex': 1.9230769230769231,
#   'gobernadores': 1.9230769230769231,
#   'méxico': 1.9230769230769231,
#   'carlos': 1.9230769230769231,
#   'hank': 1.9230769230769231,
#   'enrique': 2.7777777777777777,
#   'peña': 2.7777777777777777,
#   'acumularon': 1.9230769230769231,
#   'últimos': 1.9230769230769231,
#   'años': 1.9230769230769231,
#   'alrededor': 1.9230769230769231,
#   'mil': 1.9230769230769231,
#   'millones': 1.9230769230769231,
#   'dólares': 1.9230769230769231,
#   'bienes': 1.9230769230769231,
#   'riquezas': 1.9230769230769231,
#   'asaltaron': 1.9230769230769231,
#   'presidencia': 1.9230769230769231,
#   'república': 1.9230769230769231,
#   'emilio': 1.9230769230769231,
#   'chuayffet': 1.9230769230769231,
#   'arturo': 1.9230769230769231,
#   'montiel': 1.9230769230769231,
#   'césar': 1.9230769230769231,
#   'camacho': 1.9230769230769231},
#  {'asamblea': 1.9230769230769231,
#   'toma': 1.9230769230769231,
#   'protesta': 1.9230769230769231,
#   'tejupilco': 1.9230769230769231,
#   'san': 1.9230769230769231,
#   'miguel': 1.9230769230769231,
#   'zinacantepec': 1.9230769230769231,
#   'atlacomulco': 1.9230769230769231,
#   'ixtlahuaca': 1.9230769230769231,
#   'toluca': 1.9230769230769231,
#   'tenancingo': 1.9230769230769231,
#   'degollado': 1.9230769230769231,
#   'metepec': 1.9230769230769231,
#   'huixquilucan': 1.9230769230769231,
#   'méxico': 1.9230769230769231}]

# %% [markdown]
# Definimos la función IDF
#
# $$$$

# %%
def idf(palabra, documentos):
    return log(
        len(documentos) / 
        (1+reduce(lambda cuenta, documento : cuenta + (1 if (palabra in documento) else 0), documentos, 0))
    )
# documento for documento in documentos if (palabra in documento)
# ]))

# %% [markdown]
# Calculamos el idf de todas las palabras

# %%
idfs = {
    palabra: idf(palabra, documentos) for palabra in palabras
}
idfs
# Out:
# {'andrés': 1.791759469228055,
#  'manuel': 1.791759469228055,
#  'lópez': 0.780158557549575,
#  'obrador': 0.780158557549575,
#  'denunció': 2.4849066497880004,
#  'ex': 2.4849066497880004,
#  'gobernadores': 2.4849066497880004,
#  'méxico': 1.2321436812926323,
#  'carlos': 2.4849066497880004,
#  'hank': 2.4849066497880004,
#  'enrique': 1.5686159179138452,
#  'peña': 1.2321436812926323,
#  'acumularon': 2.4849066497880004,
#  'últimos': 2.4849066497880004,
#  'años': 1.791759469228055,
#  'alrededor': 2.4849066497880004,
#  'mil': 1.791759469228055,
#  'millones': 2.0794415416798357,
#  'dólares': 2.4849066497880004,
#  'bienes': 2.4849066497880004,
#  'riquezas': 2.4849066497880004,
#  'asaltaron': 2.4849066497880004,
#  'presidencia': 2.0794415416798357,
#  'república': 2.0794415416798357,
#  'emilio': 2.4849066497880004,
#  'chuayffet': 2.0794415416798357,
#  'arturo': 2.4849066497880004,
#  'montiel': 1.791759469228055,
#  'césar': 2.4849066497880004,
#  'camacho': 2.0794415416798357,
#  'asamblea': 1.791759469228055,
#  'toma': 2.0794415416798357,
#  'protesta': 2.0794415416798357,
#  'comité': 2.0794415416798357,
#  'municipal': 2.0794415416798357,
#  'morena': 1.5686159179138452,
#  'metepec': 1.3862943611198906,
#  'conceder': 2.4849066497880004,
#  'entrevista': 2.0794415416798357,
#  'manifestó': 2.0794415416798357,
#  'indignación': 2.4849066497880004,
#  'entidad': 2.4849066497880004,
#  'mexiquense': 2.4849066497880004,
#  'corrupción': 2.0794415416798357,
#  'país': 1.2321436812926323,
#  'mismo': 2.0794415416798357,
#  'tiempo': 2.0794415416798357,
#  'primero': 2.0794415416798357,
#  'lugar': 2.4849066497880004,
#  'pobreza': 1.791759469228055,
#  'pobres': 2.0794415416798357,
#  'extrema': 2.4849066497880004,
#  'informó': 2.0794415416798357,
#  'administración': 2.4849066497880004,
#  'endeudó': 2.4849066497880004,
#  'municipios': 2.0794415416798357,
#  'ahora': 1.5686159179138452,
#  'alcaldías': 2.4849066497880004,
#  'dinero': 2.4849066497880004,
#  'autorizó': 2.4849066497880004,
#  'adquisición': 2.4849066497880004,
#  'deuda': 2.4849066497880004,
#  'comprometieron': 2.4849066497880004,
#  'participaciones': 2.4849066497880004,
#  'federales': 2.0794415416798357,
#  'contrastes': 2.4849066497880004,
#  'mucha': 2.0794415416798357,
#  'abandono': 2.4849066497880004,
#  'si': 1.2321436812926323,
#  'modelo': 2.4849066497880004,
#  'seguir': 2.4849066497880004,
#  'premia': 2.4849066497880004,
#  'cargo': 2.4849066497880004,
#  'nacional': 1.5686159179138452,
#  'contrastó': 2.4849066497880004,
#  'esperanza': 2.4849066497880004,
#  'puede': 2.0794415416798357,
#  'tener': 2.0794415416798357,
#  'igual': 2.4849066497880004,
#  'nayarit': 2.4849066497880004,
#  'yucatán': 2.4849066497880004,
#  'tabasco': 2.4849066497880004,
#  'conocen': 2.4849066497880004,
#  'ciudadanos': 1.791759469228055,
#  'esperan': 2.4849066497880004,
#  'cosas': 2.4849066497880004,
#  'mejoren': 2.4849066497880004,
#  'priistas': 2.4849066497880004,
#  'mazo': 2.4849066497880004,
#  'junior': 2.4849066497880004,
#  'asesoría': 2.4849066497880004,
#  'mencionó': 1.5686159179138452,
#  'exhibir': 2.4849066497880004,
#  'observan': 2.4849066497880004,
#  'colonias': 2.4849066497880004,
#  'opulencia': 2.4849066497880004,
#  'gente': 2.4849066497880004,
#  'pobre': 2.4849066497880004,
#  'llamó': 2.4849066497880004,
#  'ver': 2.4849066497880004,
#  'malos': 2.0794415416798357,
#  'ojos': 2.0794415416798357,
#  'viven': 2.4849066497880004,
#  'residencias': 2.4849066497880004,
#  'lujo': 2.4849066497880004,
#  'muchas': 2.4849066497880004,
#  'personas': 2.0794415416798357,
#  'hecho': 2.4849066497880004,
#  'bajo': 2.4849066497880004,
#  'conformidad': 2.4849066497880004,
#  'ley': 2.4849066497880004,
#  'riqueza': 2.4849066497880004,
#  'mala': 2.4849066497880004,
#  'noche': 2.4849066497880004,
#  'mañana': 2.4849066497880004,
#  'acumulan': 2.4849066497880004,
#  'grandes': 2.4849066497880004,
#  'fortunas': 2.4849066497880004,
#  'ricos': 2.4849066497880004,
#  'nieto': 2.4849066497880004,
#  'hablar': 2.4849066497880004,
#  'ido': 2.4849066497880004,
#  'bien': 2.0794415416798357,
#  'vida': 2.4849066497880004,
#  'convencerlos': 2.4849066497880004,
#  'necesario': 2.0794415416798357,
#  'cambio': 2.4849066497880004,
#  'subrayó': 2.0794415416798357,
#  'recordó': 2.4849066497880004,
#  'hace': 1.791759469228055,
#  'habló': 2.4849066497880004,
#  'mal': 2.0794415416798357,
#  'interpretó': 2.4849066497880004,
#  'cómo': 2.4849066497880004,
#  'vamos': 2.4849066497880004,
#  'tranquilidad': 2.0794415416798357,
#  'paz': 2.0794415416798357,
#  'social': 1.5686159179138452,
#  'sigue': 2.0794415416798357,
#  'conviene': 2.4849066497880004,
#  'justicia': 2.4849066497880004,
#  'queremos': 2.4849066497880004,
#  'vivir': 2.4849066497880004,
#  'seguridad': 2.4849066497880004,
#  'necesitamos': 2.4849066497880004,
#  'garantizar': 2.0794415416798357,
#  'monstruosa': 2.4849066497880004,
#  'desigualdad': 2.4849066497880004,
#  'padece': 2.0794415416798357,
#  'exhorta': 2.4849066497880004,
#  'estudiantes': 2.4849066497880004,
#  'planteen': 2.4849066497880004,
#  'propuesta': 2.4849066497880004,
#  'autoridades': 1.791759469228055,
#  'universidad': 2.0794415416798357,
#  'autónomo': 2.4849066497880004,
#  'unam': 2.0794415416798357,
#  'liberarán': 2.4849066497880004,
#  'instalaciones': 2.4849066497880004,
#  'rectoría': 2.0794415416798357,
#  'obtienen': 2.4849066497880004,
#  'compromiso': 2.4849066497880004,
#  'van': 1.791759469228055,
#  'ser': 2.4849066497880004,
#  'recibimos': 2.4849066497880004,
#  'posteriormente': 2.4849066497880004,
#  'rector': 2.4849066497880004,
#  'josé': 2.4849066497880004,
#  'narro': 2.4849066497880004,
#  'den': 2.4849066497880004,
#  'conocer': 2.4849066497880004,
#  'legítimas': 2.4849066497880004,
#  'demandas': 2.4849066497880004,
#  'acción': 2.4849066497880004,
#  'observen': 2.4849066497880004,
#  'alumnos': 2.4849066497880004,
#  'quieren': 2.4849066497880004,
#  'dialogar': 2.4849066497880004,
#  'caer': 2.0794415416798357,
#  'confrontación': 2.0794415416798357,
#  'además': 2.4849066497880004,
#  'podrían': 2.4849066497880004,
#  'medios': 2.4849066497880004,
#  'comunicación': 2.4849066497880004,
#  'sencillo': 2.4849066497880004,
#  'empecinan': 2.4849066497880004,
#  'partes': 2.4849066497880004,
#  'solo': 2.0794415416798357,
#  'apuestan': 2.4849066497880004,
#  'violencia': 1.5686159179138452,
#  'va': 2.0794415416798357,
#  'llegar': 2.4849066497880004,
#  'ningún': 2.4849066497880004,
#  'lado': 2.4849066497880004,
#  'debe': 1.791759469228055,
#  'autonomía': 2.4849066497880004,
#  'policía': 2.4849066497880004,
#  'actúen': 2.4849066497880004,
#  'responsablemente': 2.4849066497880004,
#  'opinó': 2.4849066497880004,
#  'movimiento': 1.5686159179138452,
#  'magisterial': 2.4849066497880004,
#  'revisar': 2.4849066497880004,
#  'llamada': 2.4849066497880004,
#  'reforma': 2.4849066497880004,
#  'educativa': 2.4849066497880004,
#  'mejorar': 2.4849066497880004,
#  'calidad': 2.4849066497880004,
#  'enseñanza': 2.4849066497880004,
#  'dar': 2.4849066497880004,
#  'oportunidades': 2.4849066497880004,
#  'estudiar': 2.4849066497880004,
#  'sino': 2.4849066497880004,
#  'asunto': 2.4849066497880004,
#  'laboral': 1.791759469228055,
#  'político': 2.4849066497880004,
#  'escuchen': 2.4849066497880004,
#  'maestros': 2.4849066497880004,
#  'diálogo': 2.4849066497880004,
#  'parte': 2.4849066497880004,
#  'estatales': 2.4849066497880004,
#  'asegurar': 2.4849066497880004,
#  'regeneración': 2.0794415416798357,
#  'lucha': 2.0794415416798357,
#  'menos': 2.0794415416798357,
#  'ven': 2.4849066497880004,
#  'expresó': 2.4849066497880004,
#  'importa': 2.4849066497880004,
#  'quién': 2.4849066497880004,
#  'pan': 2.4849066497880004,
#  'pri': 2.4849066497880004,
#  'embargo': 2.0794415416798357,
#  'empeorando': 2.4849066497880004,
#  'situación': 2.4849066497880004,
#  'económica': 2.0794415416798357,
#  'política': 2.0794415416798357,
#  'pura': 2.4849066497880004,
#  'publicidad': 2.4849066497880004,
#  'puro': 2.4849066497880004,
#  'circo': 2.4849066497880004,
#  'mientras': 2.4849066497880004,
#  'siga': 2.4849066497880004,
#  'inalterable': 2.4849066497880004,
#  'antipopular': 2.4849066497880004,
#  'entreguista': 2.4849066497880004,
#  'sólo': 2.4849066497880004,
#  'beneficia': 2.4849066497880004,
#  'pequeña': 2.4849066497880004,
#  'minoría': 2.4849066497880004,
#  'costa': 2.4849066497880004,
#  'sufrimiento': 2.4849066497880004,
#  'pueblo': 2.0794415416798357,
#  'continuará': 2.4849066497880004,
#  'crisis': 2.4849066497880004,
#  'bienestar': 2.0794415416798357,
#  'inseguridad': 2.4849066497880004,
#  'expuso': 2.4849066497880004,
#  'equivocación': 2.4849066497880004,
#  'habla': 2.4849066497880004,
#  'impulsar': 2.0794415416798357,
#  'actividades': 2.4849066497880004,
#  'productivas': 2.4849066497880004,
#  'generar': 2.4849066497880004,
#  'empleos': 2.4849066497880004,
#  'principal': 2.4849066497880004,
#  'problema': 2.4849066497880004,
#  'nación': 2.4849066497880004,
#  'crecimiento': 2.4849066497880004,
#  'económico': 2.4849066497880004,
#  'haber': 2.4849066497880004,
#  'economía': 1.791759469228055,
#  'mexicana': 2.4849066497880004,
#  'crecerá': 2.4849066497880004,
#  'ciento': 1.791759469228055,
#  'significa': 2.4849066497880004,
#  'generarán': 2.4849066497880004,
#  'trabajos': 2.4849066497880004,
#  'jóvenes': 2.0794415416798357,
#  'ingresando': 2.4849066497880004,
#  'mercado': 2.4849066497880004,
#  'quedarán': 2.0794415416798357,
#  'desempleo': 2.0794415416798357,
#  'necesita': 2.4849066497880004,
#  'anualmente': 2.4849066497880004,
#  'millón': 2.4849066497880004,
#  'cubrir': 2.4849066497880004,
#  'toda': 2.4849066497880004,
#  'demanda': 2.4849066497880004,
#  'necesitaría': 2.4849066497880004,
#  'crecer': 2.4849066497880004,
#  'tasa': 2.4849066497880004,
#  'promedio': 2.4849066497880004,
#  'anual': 2.4849066497880004,
#  'contrario': 2.4849066497880004,
#  'posibilidad': 2.4849066497880004,
#  'trabajo': 2.4849066497880004,
#  'refugiarse': 2.4849066497880004,
#  'informal': 2.0794415416798357,
#  'dio': 2.4849066497880004,
#  'dato': 2.4849066497880004,
#  'actualmente': 2.4849066497880004,
#  'mitad': 2.4849066497880004,
#  'población': 2.4849066497880004,
#  'económicamente': 2.4849066497880004,
#  'activa': 2.4849066497880004,
#  'edad': 2.4849066497880004,
#  'trabajar': 2.4849066497880004,
#  'encuentra': 2.4849066497880004,
#  'tendencia': 2.4849066497880004,
#  'mexicanos': 2.4849066497880004,
#  'sobreviviendo': 2.4849066497880004,
#  'propuso': 2.4849066497880004,
#  'gobierno': 2.4849066497880004,
#  'peñista': 2.4849066497880004,
#  'atender': 2.4849066497880004,
#  'problemática': 2.4849066497880004,
#  'vez': 2.0794415416798357,
#  'auspiciar': 2.4849066497880004,
#  'carestía': 2.4849066497880004,
#  'aumentar': 2.4849066497880004,
#  'precios': 2.4849066497880004,
#  'energéticos': 2.4849066497880004,
#  'hizo': 2.4849066497880004,
#  'panista': 2.4849066497880004,
#  'felipe': 2.4849066497880004,
#  'calderón': 2.4849066497880004,
#  'priista': 2.4849066497880004,
#  'aplicar': 2.4849066497880004,
#  'iva': 2.4849066497880004,
#  'alimentos': 2.4849066497880004,
#  'medicamentos': 2.4849066497880004,
#  'explicar': 2.4849066497880004,
#  'lograr': 2.4849066497880004,
#  'transformación': 2.4849066497880004,
#  'manera': 2.4849066497880004,
#  'pacífica': 2.4849066497880004,
#  'retomó': 2.4849066497880004,
#  'pensamiento': 2.4849066497880004,
#  'joven': 2.4849066497880004,
#  'tejupilco': 2.0794415416798357,
#  'potentados': 2.4849066497880004,
#  'preocupa': 2.4849066497880004,
#  'temen': 2.4849066497880004,
#  'consciente': 2.4849066497880004,
#  'organizado': 2.4849066497880004,
#  'enojado': 2.4849066497880004,
#  'violento': 2.4849066497880004,
#  'indicó': 2.4849066497880004,
#  'muchacho': 2.4849066497880004,
#  'razón': 2.4849066497880004,
#  'trampa': 2.4849066497880004,
#  'gobiernan': 2.4849066497880004,
#  'quisieran': 2.4849066497880004,
#  'perdieran': 2.4849066497880004,
#  'estribos': 2.4849066497880004,
#  'cayéramos': 2.4849066497880004,
#  'provocación': 2.4849066497880004,
#  'camino': 2.4849066497880004,
#  'destruir': 2.4849066497880004,
#  'autoritarismo': 2.4849066497880004,
#  'perpetua': 2.4849066497880004,
#  'pacífico': 2.4849066497880004,
#  'requiere': 2.4849066497880004,
#  'organización': 2.4849066497880004,
#  'paciencia': 2.4849066497880004,
#  'invitó': 2.4849066497880004,
#  'participar': 2.4849066497880004,
#  'próximo': 2.4849066497880004,
#  'noviembre': 2.4849066497880004,
#  'estatal': 2.4849066497880004,
#  'llevará': 2.4849066497880004,
#  'cabo': 2.4849066497880004,
#  'plaza': 2.4849066497880004,
#  'mártires': 2.4849066497880004,
#  'capital': 2.4849066497880004,
#  'tarde': 2.4849066497880004,
#  'asistió': 2.4849066497880004,
#  'ceremonia': 2.4849066497880004,
#  'integrantes': 2.4849066497880004,
#  'huixquilucan': 2.0794415416798357,
#  'jueves': 2.4849066497880004,
#  'domingo': 2.4849066497880004,
#  'recorrió': 2.4849066497880004,
#  'zitácuaro': 2.4849066497880004,
#  'michoacán': 2.4849066497880004,
#  'valle': 2.4849066497880004,
#  'bravo': 2.4849066497880004,
#  'san': 2.4849066497880004,
#  'miguel': 2.4849066497880004,
#  'zinacantepec': 2.4849066497880004,
#  'atlacomulco': 2.4849066497880004,
#  'ixtlahuaca': 2.4849066497880004,
#  'toluca': 2.4849066497880004,
#  'tenancingo': 2.4849066497880004,
#  'degollado': 2.4849066497880004}

# %% [markdown]
# Calculamos tfxIDF

# %%
tfidfs = [
    {
        palabra: idfs[palabra]*tf
        for (palabra, tf) in tf_n.items()
    }
    for tf_n in tfs
]
tfidfs
# Out:
# [{'andrés': 3.445691286977029,
#   'manuel': 3.445691286977029,
#   'lópez': 1.5003049183645674,
#   'obrador': 1.5003049183645674,
#   'denunció': 4.778666634207693,
#   'ex': 4.778666634207693,
#   'gobernadores': 4.778666634207693,
#   'méxico': 2.3695070794089084,
#   'carlos': 4.778666634207693,
#   'hank': 4.778666634207693,
#   'enrique': 4.35726643864957,
#   'peña': 3.4226213369239784,
#   'acumularon': 4.778666634207693,
#   'últimos': 4.778666634207693,
#   'años': 3.445691286977029,
#   'alrededor': 4.778666634207693,
#   'mil': 3.445691286977029,
#   'millones': 3.998926041691992,
#   'dólares': 4.778666634207693,
#   'bienes': 4.778666634207693,
#   'riquezas': 4.778666634207693,
#   'asaltaron': 4.778666634207693,
#   'presidencia': 3.998926041691992,
#   'república': 3.998926041691992,
#   'emilio': 4.778666634207693,
#   'chuayffet': 3.998926041691992,
#   'arturo': 4.778666634207693,
#   'montiel': 3.445691286977029,
#   'césar': 4.778666634207693,
#   'camacho': 3.998926041691992},
#  {'asamblea': 3.445691286977029,
#   'toma': 3.998926041691992,
#   'protesta': 3.998926041691992,
#   'comité': 3.998926041691992,
#   'municipal': 3.998926041691992,
#   'morena': 3.016569072911241,
#   'metepec': 2.665950694461328,
#   'conceder': 4.778666634207693,
#   'entrevista': 3.998926041691992,
#   'lópez': 1.5003049183645674,
#   'obrador': 1.5003049183645674,
#   'manifestó': 3.998926041691992,
#   'indignación': 4.778666634207693,
#   'entidad': 4.778666634207693,
#   'mexiquense': 4.778666634207693,
#   'corrupción': 3.998926041691992,
#   'país': 2.3695070794089084,
#   'mismo': 3.998926041691992,
#   'tiempo': 3.998926041691992,
#   'primero': 3.998926041691992,
#   'lugar': 4.778666634207693,
#   'pobreza': 4.977109636744597,
#   'millones': 5.7762265046662105,
#   'pobres': 3.998926041691992,
#   'extrema': 4.778666634207693},
#  {'informó': 3.998926041691992,
#   'administración': 4.778666634207693,
#   'enrique': 3.016569072911241,
#   'peña': 2.3695070794089084,
#   'endeudó': 4.778666634207693,
#   'méxico': 2.3695070794089084,
#   'municipios': 3.998926041691992,
#   'ahora': 3.016569072911241,
#   'alcaldías': 4.778666634207693,
#   'dinero': 4.778666634207693,
#   'autorizó': 4.778666634207693,
#   'adquisición': 4.778666634207693,
#   'deuda': 4.778666634207693,
#   'comprometieron': 4.778666634207693,
#   'participaciones': 4.778666634207693,
#   'federales': 3.998926041691992},
#  {'contrastes': 4.778666634207693,
#   'mucha': 5.7762265046662105,
#   'corrupción': 3.998926041691992,
#   'pobreza': 3.445691286977029,
#   'abandono': 4.778666634207693,
#   'si': 2.3695070794089084,
#   'modelo': 4.778666634207693,
#   'seguir': 4.778666634207693,
#   'premia': 4.778666634207693,
#   'ahora': 3.016569072911241,
#   'ahora': 3.016569072911241,
#   'hace': 3.445691286977029,
#   'priista': 4.778666634207693,
#   'enrique': 3.016569072911241,
#   'peña': 2.3695070794089084,
#   'aplicar': 4.778666634207693,
#   'iva': 4.778666634207693,
#   'alimentos': 4.778666634207693,
#   'medicamentos': 4.778666634207693},
#  {'explicar': 4.778666634207693,
#   'morena': 3.016569072911241,
#   'lucha': 3.998926041691992,
#   'lograr': 4.778666634207693,
#   'transformación': 4.778666634207693,
#   'país': 2.3695070794089084,
#   'manera': 4.778666634207693,
#   'pacífica': 4.778666634207693,
#   'violencia': 3.016569072911241,
#   'lópez': 1.5003049183645674,
#   'obrador': 1.5003049183645674,
#   'retomó': 4.778666634207693,
#   'pensamiento': 4.778666634207693,
#   'joven': 4.778666634207693,
#   'tejupilco': 3.998926041691992,
#   'potentados': 4.778666634207693,
#   'preocupa': 4.778666634207693,
#   'temen': 4.778666634207693,
#   'pueblo': 5.7762265046662105,
#   'consciente': 4.778666634207693,
#   'organizado': 4.778666634207693,
#   'enojado': 4.778666634207693,
#   'violento': 4.778666634207693},
#  {'indicó': 4.778666634207693,
#   'muchacho': 4.778666634207693,
#   'razón': 4.778666634207693,
#   'caer': 3.998926041691992,
#   'violencia': 5.602199706835162,
#   'trampa': 4.778666634207693,
#   'mal': 3.998926041691992,
#   'gobiernan': 4.778666634207693,
#   'país': 2.3695070794089084,
#   'quisieran': 4.778666634207693,
#   'perdieran': 4.778666634207693,
#   'estribos': 4.778666634207693,
#   'cayéramos': 4.778666634207693,
#   'provocación': 4.778666634207693,
#   'camino': 4.778666634207693,
#   'vez': 3.998926041691992,
#   'destruir': 4.778666634207693,
#   'autoritarismo': 4.778666634207693,
#   'perpetua': 4.778666634207693,
#   'morena': 3.016569072911241,
#   'movimiento': 3.016569072911241,
#   'pacífico': 4.778666634207693,
#   'requiere': 4.778666634207693,
#   'mucha': 5.7762265046662105,
#   'organización': 4.778666634207693,
#   'paciencia': 4.778666634207693,
#   'mencionó': 3.016569072911241},
#  {'lópez': 1.5003049183645674,
#   'obrador': 1.5003049183645674,
#   'invitó': 4.778666634207693,
#   'ciudadanos': 3.445691286977029,
#   'metepec': 2.665950694461328,
#   'participar': 4.778666634207693,
#   'próximo': 4.778666634207693,
#   'noviembre': 4.778666634207693,
#   'asamblea': 3.445691286977029,
#   'estatal': 4.778666634207693,
#   'movimiento': 3.016569072911241,
#   'regeneración': 3.998926041691992,
#   'nacional': 3.016569072911241,
#   'llevará': 4.778666634207693,
#   'cabo': 4.778666634207693,
#   'plaza': 4.778666634207693,
#   'mártires': 4.778666634207693,
#   'capital': 4.778666634207693},
#  {'tarde': 4.778666634207693,
#   'asistió': 4.778666634207693,
#   'ceremonia': 4.778666634207693,
#   'toma': 3.998926041691992,
#   'protesta': 3.998926041691992,
#   'integrantes': 4.778666634207693,
#   'comité': 3.998926041691992,
#   'municipal': 3.998926041691992,
#   'morena': 3.016569072911241,
#   'huixquilucan': 3.998926041691992,
#   'méxico': 2.3695070794089084},
#  {'jueves': 4.778666634207693,
#   'domingo': 4.778666634207693,
#   'andrés': 3.445691286977029,
#   'manuel': 3.445691286977029,
#   'lópez': 1.5003049183645674,
#   'obrador': 1.5003049183645674,
#   'recorrió': 4.778666634207693,
#   'municipios': 3.998926041691992,
#   'zitácuaro': 4.778666634207693,
#   'michoacán': 4.778666634207693,
#   'valle': 4.778666634207693,
#   'bravo': 4.778666634207693,
#   'tejupilco': 3.998926041691992,
#   'san': 4.778666634207693,
#   'miguel': 4.778666634207693,
#   'zinacantepec': 4.778666634207693,
#   'atlacomulco': 4.778666634207693,
#   'ixtlahuaca': 4.778666634207693,
#   'toluca': 4.778666634207693,
#   'tenancingo': 4.778666634207693,
#   'degollado': 4.778666634207693,
#   'metepec': 2.665950694461328,
#   'huixquilucan': 3.998926041691992,
#   'méxico': 2.3695070794089084}]

# %%
def obtener_keywords(num_keywords=5):
    keywords = []
    for tfidf_n in tfidfs:
        keywords_n = sorted(tfidf_n.items() ,  key=lambda x: x[1], reverse=True)[:num_keywords]
#         print([keyword[0] for keyword in keywords_n])
        keywords.append([keyword[0] for keyword in keywords_n])
    return keywords

# %%
keywords = obtener_keywords(6)
keywords
# Out:
# [['denunció', 'ex', 'gobernadores', 'carlos', 'hank', 'acumularon'],
#  ['millones', 'pobreza', 'conceder', 'indignación', 'entidad', 'mexiquense'],
#  ['administración',
#   'endeudó',
#   'alcaldías',
#   'dinero',
#   'autorizó',
#   'adquisición'],
#  ['mucha', 'contrastes', 'abandono', 'modelo', 'seguir', 'premia'],
#  ['esperanza', 'igual', 'nayarit', 'yucatán', 'tabasco', 'conocen'],
#  ['colonias', 'exhibir', 'observan', 'opulencia', 'gente', 'pobre'],
#  ['riqueza', 'mala', 'noche', 'mañana', 'acumulan', 'grandes'],
#  ['justicia', 'paz', 'recordó', 'habló', 'interpretó', 'cómo'],
#  ['exhorta', 'estudiantes', 'planteen', 'propuesta', 'autónomo', 'liberarán'],
#  ['acción', 'observen', 'alumnos', 'quieren', 'dialogar', 'además'],
#  ['sencillo', 'empecinan', 'partes', 'apuestan', 'llegar', 'ningún'],
#  ['magisterial', 'revisar', 'llamada', 'reforma', 'educativa', 'mejorar'],
#  ['asegurar', 'ven', 'expresó', 'importa', 'quién', 'pan'],
#  ['económica',
#   'mientras',
#   'siga',
#   'inalterable',
#   'antipopular',
#   'entreguista'],
#  ['empleos',
#   'crecimiento',
#   'económico',
#   'bienestar',
#   'expuso',
#   'equivocación'],
#  ['trabajos', 'solo', 'mil', 'mexicana', 'crecerá', 'significa'],
#  ['economía', 'cubrir', 'toda', 'demanda', 'necesitaría', 'crecer'],
#  ['informal', 'economía', 'dio', 'dato', 'actualmente', 'mitad'],
#  ['propuso', 'gobierno', 'peñista', 'atender', 'problemática', 'auspiciar'],
#  ['pueblo', 'explicar', 'lograr', 'transformación', 'manera', 'pacífica'],
#  ['mucha', 'violencia', 'indicó', 'muchacho', 'razón', 'trampa'],
#  ['invitó', 'participar', 'próximo', 'noviembre', 'estatal', 'llevará'],
#  ['tarde', 'asistió', 'ceremonia', 'integrantes', 'toma', 'protesta'],
#  ['jueves', 'domingo', 'recorrió', 'zitácuaro', 'michoacán', 'valle']]

# %% [markdown]
# ### Palabras clave por párrafo

# %%
keywords_dict = {'Párrafo {0}'.format(n+1):kw_n for (n, kw_n) in enumerate(keywords)}
df = DataFrame(keywords_dict).transpose()
df
# Out:
#                          0            1             2               3  \
# Párrafo 1         denunció           ex  gobernadores          carlos
# Párrafo 2         millones      pobreza      conceder     indignación
# Párrafo 3   administración      endeudó     alcaldías          dinero
# Párrafo 4            mucha   contrastes      abandono          modelo
# Párrafo 5        esperanza        igual       nayarit         yucatán
# Párrafo 6         colonias      exhibir      observan       opulencia
# Párrafo 7          riqueza         mala         noche          mañana
# Párrafo 8         justicia          paz       recordó           habló
# Párrafo 9          exhorta  estudiantes      planteen       propuesta
# Párrafo 10          acción     observen       alumnos         quieren
# Párrafo 11        sencillo    empecinan        partes        apuestan
# Párrafo 12     magisterial      revisar       llamada         reforma
# Párrafo 13        asegurar          ven       expresó         importa
# Párrafo 14       económica     mientras          siga     inalterable
# Párrafo 15         empleos  crecimiento     económico       bienestar
# Párrafo 16        trabajos         solo           mil        mexicana
# Párrafo 17        economía       cubrir          toda         demanda
# Párrafo 18        informal     economía           dio            dato
# Párrafo 19         propuso     gobierno       peñista         atender
# Párrafo 20          pueblo     explicar        lograr  transformación
# Párrafo 21           mucha    violencia        indicó        muchacho
# Párrafo 22          invitó   participar       próximo       noviembre
# Párrafo 23           tarde      asistió     ceremonia     integrantes
# Párrafo 24          jueves      domingo      recorrió       zitácuaro
#
#                        4             5
# Párrafo 1           hank    acumularon
# Párrafo 2        entidad    mexiquense
# Párrafo 3       autorizó   adquisición
# Párrafo 4         seguir        premia
# Párrafo 5        tabasco       conocen
# Párrafo 6          gente         pobre
# Párrafo 7       acumulan       grandes
# Párrafo 8     interpretó          cómo
# Párrafo 9       autónomo     liberarán
# Párrafo 10      dialogar        además
# Párrafo 11        llegar        ningún
# Párrafo 12     educativa       mejorar
# Párrafo 13         quién           pan
# Párrafo 14   antipopular   entreguista
# Párrafo 15        expuso  equivocación
# Párrafo 16       crecerá     significa
# Párrafo 17   necesitaría        crecer
# Párrafo 18   actualmente         mitad
# Párrafo 19  problemática     auspiciar
# Párrafo 20        manera      pacífica
# Párrafo 21         razón        trampa
# Párrafo 22       estatal       llevará
# Párrafo 23          toma      protesta
# Párrafo 24     michoacán         valle

# %% [markdown]
# ### Palabras más usadas

# %%
DataFrame(sorted(cuenta_total_palabras.items(),  key=lambda x: x[1], reverse=True)[:15], columns=['Palabra', 'Cuenta'])
# Out:
#       Palabra  Cuenta
# 0       lópez      10
# 1     obrador      10
# 2          si       9
# 3        peña       7
# 4      méxico       6
# 5        país       6
# 6   violencia       6
# 7     enrique       5
# 8     metepec       5
# 9      social       5
# 10   economía       5
# 11        mil       4
# 12     morena       4
# 13    pobreza       4
# 14      ahora       4
