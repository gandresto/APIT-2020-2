# %% [markdown]
# # Term Frecuency x Inverse Document Frecuency (TF IDF)

# %%
import io
import re
from functools import reduce
from collections import Counter
from numpy import log
from pandas import DataFrame

# %%
with io.open('stop-words-spanish.txt', mode='r', encoding='utf-8') as f:
    stopwords = f.read().splitlines()
# stopwords

# %%
# AMLO_28042013
with io.open('Data/AMLO_20180401.txt', mode='r', encoding='utf-8') as f:
    boletin = f.read().splitlines()
boletin
# Out:
# ['Andrés Manuel López Obrador, candidato a la Presidencia de México, inicia en Santa Catarina un recorrido por municipios de Nuevo Léon.',
#  'Más tarde encabezará asamblea en la plaza principal de Ciudad Benito Juárez y a las 18:00 horas en la plaza central de Apodaca, N.L.',
#  'Santa Catarina, Nuevo León, 02 de abril de 2018.-  Andrés Manuel López Obrador aseguró que en campaña todo será amor y paz, “que se ahorren cualquier provocación los candidatos de los otros partidos, porque no voy a contestarles”, “no me voy a enganchar en ningún debate, no me voy a enojar”.',
#  'Informó que sus asesores de los pueblos de México me están recomendando que yo no me enoje, que no conteste a ninguna provocación y recalcó que no va a polemizar, no va a testerear, ni caerá en ninguna provocación de sus adversarios.',
#  'En otro tema, López Obrador adelantó que no pasará nada el primero de julio cuando se lleven a cabo las elecciones presidenciales, “lo único que va a suceder es de que se va a iniciar una transformación en México, va a ganar nuestro movimiento, estamos 20 puntos arriba”.',
#  'Señaló que entiende que estén nerviosos sus adversarios, pero ahora ya salió una dosis mayor, ya no es de 80, sino de 160 miligramos, una dosis de “AMLODIPINO” que ayuda mucho a serenarse, a tranquilizarse.',
#  'A la pregunta de los reporteros sobre la situación de violencia que prevalece al norte del país, ¿cómo puede afectar en las elecciones en el país, están pidiendo medidas extras para la elección?, López Obrador respondió que seguirá recorriendo todos los pueblos sin escoltas, sin guardaespaldas, porque el que lucha por la justicia no tiene nada que ver.',
#  'A la pregunta de los reporteros sobre con qué países impulsará acuerdos comerciales en caso de que se caiga el TLC, porque hoy por segundo día Donald Trump vuelve a decir que si no se resuelven los problemas de migración se cae el DACA y el TLC, el candidato a la Presidencia de México dijo que esperará que Donald Trump se serene y lo hará entrar en razón.',
#  '“Ya falta para que se logré una buena renegociación del Tratado que se incluya el aumento de los salarios de los trabajadores en México, porque hay mucha desigualdad salarial”, mencionó al dar un dato: un trabajador de la industria automotriz en Chicago gana 34 dólares la hora y un trabajador en la misma especialización en Ciudad Juárez, Chihuahua gana 3 dólares la hora.',
#  'Señaló que en la negociación del TLC se tiene que incluir: el aumento del salario y se incluya el tema migratorio, y en su momento se convencerá a Trump que los problemas económicos, sociales de los pueblos de Estados Unidos y México no se resuelven con muros, ni con amenazas de mano dura, ni con la militarización de la frontera, se resuelven si hay desarrollo, si hay empleo, buenos salarios y bienestar.',
#  '“Lo vamos a convencer de que necesitamos tener cooperación para el desarrollo, va a haber una relación con Estados Unidos respetuosa, de respeto mutuo, nos vamos a entender con el gobierno estadounidense”, expresó.',
#  'Andrés Manuel López Obrador invitó a que se realice un encuentro público entre 5 técnicos del Consejo Coordinador Empresarial, 5 técnicos del gobierno federal y “5 técnicos de nosotros”, para debatir si es viable o no la construcción del nuevo aeropuerto en el Lago de Texcoco.',
#  'El candidato por la coalición “Juntos haremos historia” a la Presidencia de la República puntualizó que los 5 técnicos de la propuesta alternativa estará encabezado por el próximo secretario de Comunicaciones del gobierno democrático, Javier Jiménez Espriú, estará acompañado por los ingenieros: José María Rioboo, Sergio Samaniego y otros más.',
#  '“Sería muy bueno que se lleve a cabo ya la mesa y que participen los medios de información, que sea a la vista de todos, que estos 15 técnicos den a conocer todos sus argumentos, se conozca bien el proyecto y de esa manera se resuelva”, comentó.',
#  'Señaló que se invitarán a los representantes de los medios de comunicación, el pueblo de México contará con todos los elementos sobre el tema, así como se den a conocer quiénes son los beneficiados con esos contratos, a cuánto ascienden el presupuesto que se destinará, en cuánto tiempo terminarán el nuevo aeropuerto.',
#  '“Porque están hablando de que se terminaría hasta finales del próximo sexenio, entonces a nosotros nos va a tocar pagando los compromisos que ya se están haciendo por anticipado, todo esto habría que analizarlo”, sostuvo.',
#  'Sostuvo que lo más importante es que se lleve a cabo la revisión de los contratos para que se pueda demostrar que es mucho mejor el proyecto alternativo que encabeza, más económico, más eficiente, más viable que lo que ellos proponen.',
#  'Expresó que la mesa de trabajo entre los técnicos servirá para que “ellos nos convenzan o que nosotros les demos a conocer nuestro proyecto que es mejor que lo que ellos están proponiendo”.',
#  'En entrevista al finalizar el encuentro con los ciudadanos de Santa Catarina, Nuevo León, expresó que hay disposición para que la mesa se lleve a cabo, pero que no vayan a salir con evasivas, porque son muy buenos para hacerse los occisos, es decir, no dar la cara y mandar ahí a sus representantes.',
#  'A la pregunta de los reporteros de que ayer menciona de nueva cuenta que cancelará el nuevo aeropuerto, pero entonces en qué quedó la mesa con especialistas, López Obrador respondió que está esperando que acepten la propuesta de revisar los contratos del aeropuerto.',
#  'Sobre cuándo se podría dar la reunión entre los técnicos, López Obrador sostuvo que esperará pacientemente, porque todavía no ha dado una respuesta el presidente del Consejo Coordinador Empresarial, que el que se comprometió a que iba a llevar a cabo esta mesa para transparentar los contratos.',
#  '“Nosotros tenemos nuestro proyecto alternativo que es la construcción de dos pistas en el aeropuerto militar de Santa Lucía y ahorrarnos más de 200 mil millones de pesos, pero si ellos sostienen que es viable construir el aeropuerto en el Lago de Texcoco, entonces tendrían ellos que demostrarlo”, comentó.',
#  'Prosiguió que tendrían que convencer a los técnicos que sostienen que es inviable esa obra, porque se escogió el peor lugar en el Valle de México, es donde hay más hundimiento, hay un hundimiento de alrededor de un metro por año en esa zona.',
#  'Recordó que ha dicho que “se puede construir un aeropuerto en medio del Océano Pacífico o del Océano Atlántico, nada más que cuesta muchísimo dinero, este es el caso de querer construir este aeropuerto en el Lago de Texcoco, este es un barril sin fondo”.',
#  'López Obrador aseguró que la construcción del nuevo aeropuerto en el Lago de Texcoco significa: “un socavón, un barril sin fondo, es un monumento a la corrupción”.',
#  'El candidato por la coalición “Juntos haremos historia” se reunió con los habitantes de Santa Catarina, Nuevo León y más tarde estará en Ciudad Benito Juárez, así como Apodaca, Nuevo León.',
#  'Durante el primer evento del día, Andrés Manuel López Obrador aseguró que el cambio va a ser real y a fondo, no va a ser por encimita, no va a ser maquillaje, se arrancará de raíz este régimen corrupto, de injusticias, de privilegios y se hará de forma pacífica, pero a fondo.',
#  'Manifestó que en el nuevo gobierno democrático no se privatizará nada: ni el agua, ni la salud “y ya se terminó ese periodo neoliberal, ya está llegando a su fin esa política”.',
#  'Indicó que se desterrará la corrupción de México y se ahorrará mucho dinero, se bajarán los sueldos de los funcionarios de más alto nivel, porque van a ganar más los de abajo: los maestros, las enfermeras, los médicos, los policías, los soldaos, los marinos, los que trabajan al servicio del estado, es decir, se mejorará salario de los trabajadores.',
#  'Se comprometió a garantizar el derecho al estudio y al trabajo de los jóvenes, la educación pública será gratuita en todos los niveles escolares y reafirmó su compromiso que al triunfo del movimiento que encabeza se cancelará la mal llamada reforma educativa y se elaborará un plan educativo para mejorar la calidad de la enseñanza, sin afectar los derechos laborales de los maestros.',
#  'Expresó que a partir del primero de diciembre todos los adultos mayores del país van a tener una pensión del doble de lo que reciben en la actualidad, así como tendrán apoyos las personas con discapacidad.',
#  'Pidió a los ciudadanos no confiarse, aunque se esté arriba como 20 puntos en todas las encuestas.',
#  'Alertó que quienes mal gobiernan el país no quieren dejar de robar, no tienen llenadera y por eso van a querer robarse la elección, harán fraude a partir de la compra del voto y un ejemplo claro es que empiezan a comprar votos y reparten frijol con gorgojo, tinacos, son unos sinvergüenzas.',
#  '“Ahora andan diciendo que sí ganamos se van a acabar los programas sociales, ya no va a haber el llamado Prospera según ellos, lo que no va a haber es el \xa0Prospera para los corruptos, el pueblo va a tener más apoyos en todos los sentidos, porque será el gobierno del pueblo y para el pueblo”, externó.',
#  'Agradeció el patrocinio que se da al béisbol en Nuevo León y puso como ejemplo que el primero de mayo por primera vez se llevará a cabo un juego entre los equipos Dodgers contra Los padres de San Diego e indicó que se tiene que apoyar al béisbol, pero también a todos los deportes.',
#  'Adelantó que al triunfo del movimiento habrá educación física desde el kínder hasta la universidad.',
#  'En Santa Catarina, Nuevo León, López Obrador dedicó el acto a Rosario Ibarra de Piedra, quien es una mujer “que quiero mucho, que ha luchado por defender a los desaparecidos de este país, a quienes han sido víctimas del autoritarismo, que se va terminar al triunfo” del 1 de julio.',
#  'Tanto en Santa Catarina como en Ciudad Benito Juárez, Nuevo León tomó protesta a quienes defenderán el voto de los ciudadanos el primero de julio, con el objetivo de evitar el fraude y que haya democracia en el país.',
#  'En la tarde-noche, López Obrador estará en Apodaca y mañana visitará en San Pedro, Coahuila y Gómez Palacio, Durango.']

# %% [markdown]
# ### Obtener palabras
#
# Obtenemos las palabras en minúsculas

# %%
documentos = [re.findall('[a-zA-zñáéíóúüÁÉÍÓÚÜÑ]+', parrafo.lower()) for (index, parrafo) in enumerate(boletin)]
# documentos

# %% [markdown]
# Obtenemos documentos sin stopwords

# %%
documentos = [[palabra for palabra in documento if not (palabra in stopwords)] for documento in documentos]
total_palabras = len(documentos)
# documentos

# %% [markdown]
# Contar las palabras por documento y el total de palabras

# %%
cuenta_por_documento = [Counter(parrafo) for parrafo in documentos]
cuenta_total_palabras = reduce((lambda x, y: x + y), cuenta_por_documento)
palabras = [palabra for (palabra, cuenta) in cuenta_total_palabras.items()]
# cuenta_por_documento

# %% [markdown]
# Definimos función para suavizar la cuenta de palabras.

# %%
def bm25(contador, k=25):
    return {
        key: ((cuenta + 1)*k)/(cuenta+k) for (key, cuenta) in contador.items()
    }

# %% [markdown]
# Calculamos tf para cada uno de los documentos

# %%
tfs = [bm25(c_doc) for c_doc in cuenta_por_documento]
# tfs

# %% [markdown]
# Definimos la función IDF

# %%
def idf(palabra, documentos):
    return log(
        len(documentos) / 
        (1+reduce(lambda cuenta, documento : cuenta + (1 if (palabra in documento) else 0), documentos, 0))
    )
# documento for documento in documentos if (palabra in documento)
# ]))

# %% [markdown]
# Calculamos el idf de todas las palabras

# %%
idfs = {
    palabra: idf(palabra, documentos) for palabra in palabras
}
# idfs

# %% [markdown]
# Calculamos tfxIDF

# %%
tfidfs = [
    {
        palabra: idfs[palabra]*tf
        for (palabra, tf) in tf_n.items()
    }
    for tf_n in tfs
]
# tfidfs

# %%
def obtener_keywords(num_keywords=5):
    keywords = []
    for tfidf_n in tfidfs:
        keywords_n = sorted(tfidf_n.items() ,  key=lambda x: x[1], reverse=True)[:num_keywords]
#         print([keyword[0] for keyword in keywords_n])
        keywords.append([keyword[0] for keyword in keywords_n])
    return keywords

# %%
keywords = obtener_keywords(6)
# keywords

# %% [markdown]
# ### Palabras clave por párrafo

# %%
keywords_dict = {'Párrafo {0}'.format(n+1):kw_n for (n, kw_n) in enumerate(keywords)}
df = DataFrame(keywords_dict).transpose()
df
# Out:
#                       0            1               2              3  \
# Párrafo 1        inicia    recorrido      municipios           léon
# Párrafo 2         plaza   encabezará        asamblea      principal
# Párrafo 3           voy        abril         campaña           amor
# Párrafo 4       ninguna  provocación         informó       asesores
# Párrafo 5        pasará       lleven  presidenciales          único
# Párrafo 6         dosis     entiende       nerviosos          salió
# Párrafo 7     situación    violencia       prevalece          norte
# Párrafo 8        donald          tlc           trump         países
# Párrafo 9    trabajador         gana         dólares           hora
# Párrafo 10    resuelven  negociación         incluir     migratorio
# Párrafo 11        vamos  necesitamos     cooperación       relación
# Párrafo 12     técnicos       invitó         realice        público
# Párrafo 13    república   puntualizó     alternativa     encabezado
# Párrafo 14        bueno   participen     información          vista
# Párrafo 15       cuánto    invitarán    comunicación        contará
# Párrafo 16     hablando   terminaría         finales        sexenio
# Párrafo 17   importante     revisión           pueda      demostrar
# Párrafo 18      servirá    convenzan           demos    proponiendo
# Párrafo 19   entrevista    finalizar     disposición          vayan
# Párrafo 20         ayer     menciona           nueva         cuenta
# Párrafo 21       cuándo       podría         reunión  pacientemente
# Párrafo 22          dos       pistas         militar          lucía
# Párrafo 23  hundimiento    prosiguió        inviable           obra
# Párrafo 24       océano    construir         recordó          dicho
# Párrafo 25    significa      socavón       monumento         barril
# Párrafo 26       reunió   habitantes       coalición         juntos
# Párrafo 27          ser        fondo          primer         evento
# Párrafo 28    manifestó  privatizará            agua          salud
# Párrafo 29   desterrará     ahorrará         bajarán        sueldos
# Párrafo 30   garantizar      derecho         estudio        jóvenes
# Párrafo 31    diciembre      adultos         mayores        pensión
# Párrafo 32        pidió    confiarse          aunque          todas
# Párrafo 33       alertó    gobiernan         quieren          dejar
# Párrafo 34       pueblo     prospera           haber          andan
# Párrafo 35      béisbol    agradeció      patrocinio             da
# Párrafo 36       física       kínder     universidad       adelantó
# Párrafo 37       dedicó         acto         rosario         ibarra
# Párrafo 38         tomó     protesta      defenderán       objetivo
# Párrafo 39        noche       mañana        visitará          pedro
#
#                        4               5
# Párrafo 1    presidencia          andrés
# Párrafo 2          horas         central
# Párrafo 3            paz         ahorren
# Párrafo 4   recomendando           enoje
# Párrafo 5        suceder         iniciar
# Párrafo 6          mayor            sino
# Párrafo 7           cómo        pidiendo
# Párrafo 8      impulsará        acuerdos
# Párrafo 9          falta           logré
# Párrafo 10       momento      convencerá
# Párrafo 11    respetuosa         respeto
# Párrafo 12       federal         debatir
# Párrafo 13    secretario  comunicaciones
# Párrafo 14    argumentos         conozca
# Párrafo 15     elementos         quiénes
# Párrafo 16         tocar         pagando
# Párrafo 17     económico       eficiente
# Párrafo 18       trabajo           mejor
# Párrafo 19         salir        evasivas
# Párrafo 20         quedó   especialistas
# Párrafo 21       todavía            dado
# Párrafo 22    ahorrarnos             mil
# Párrafo 23       escogió            peor
# Párrafo 24         medio        pacífico
# Párrafo 25    corrupción         aseguró
# Párrafo 26       haremos        historia
# Párrafo 27        cambio            real
# Párrafo 28       terminó         periodo
# Párrafo 29  funcionarios            alto
# Párrafo 30       pública        gratuita
# Párrafo 31         doble         reciben
# Párrafo 32     encuestas          arriba
# Párrafo 33         robar       llenadera
# Párrafo 34      diciendo         ganamos
# Párrafo 35          puso            mayo
# Párrafo 36     educación         triunfo
# Párrafo 37        piedra           mujer
# Párrafo 38        evitar      democracia
# Párrafo 39      coahuila           gómez

# %% [markdown]
# ### Palabras más usadas

# %%
DataFrame(sorted(cuenta_total_palabras.items(),  key=lambda x: x[1], reverse=True)[:15], columns=['Palabra', 'Cuenta'])
# Out:
#        Palabra  Cuenta
# 0           va      14
# 1        nuevo      13
# 2        lópez      11
# 3      obrador      11
# 4       méxico       9
# 5   aeropuerto       9
# 6     técnicos       8
# 7        santa       7
# 8         león       7
# 9     catarina       6
# 10        cabo       6
# 11        país       6
# 12          si       5
# 13    gobierno       5
# 14        mesa       5
